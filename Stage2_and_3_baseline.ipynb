# %% [markdown]
# This is Notebook 2 of 4. It does not cover Stage 2 and 3 experiments. Please refer to Notebook 3 & 4 for experiments of train_set and dev_set, as well as the accompanying report for more details.
#
# ⚙️ Runtime Notes

# %% [markdown]
#     •    Code execution may take 1 hour.
#  .

# %% [markdown]
# 📚 Navigation
#
# Use the Table of Contents on the left sidebar to navigate between sections.
#
# 🧠 Architecture Overview

# %% [markdown]
#     •    This file contains two stages.
#
#     •    The first stage consists of three few-shot models, each corresponding to a function:
#
#     •    classify_with_local_llm: selects the most similar example using cosine similarity.
#
#     •    classify_with_cot: builds a chain of thought based on the first model.
#
#     •    classify_with_fix_examples: uses fixed examples.
#
#     •    The second stage is implemented in combine_method, which selects the final label using majority voting. It applies weights of [0.4, 0.3, 0.3] to the three models and chooses the label that appears most frequently as the result.

# %% [markdown]
# 🧪 Experiment Section

# %% [markdown]
#     •    experiments conducted for Stage 2&3 is in another2 Notebooks

# %% [markdown]
# Thank you 🙂

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **combine**

# %%
import os
import json
import numpy as np
from tqdm.auto import tqdm, trange
import torch
from sentence_transformers import SentenceTransformer, losses, InputExample, CrossEncoder
from torch.utils.data import DataLoader
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import random
from google.colab import drive
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import login
from collections import defaultdict
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

HF_TOKEN = os.environ.get("HF_TOKEN")

if HF_TOKEN is None:
    raise ValueError("Hugging Face token not found. Please set HF_TOKEN in your .env file.")

login(HF_TOKEN)

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
class ImprovedDualEncoderRetrieval:
    def __init__(self,
                 retriever_model="sentence-transformers/multi-qa-mpnet-base-dot-v1",
                 reranker_model="cross-encoder/ms-marco-MiniLM-L-12-v2",
                 batch_size=16,
                 max_seq_length=512,
                 use_pooling="mean"):

        self.retriever_model = retriever_model

        # Retriever
        print(f"✅ Loading retriever model [{retriever_model}] in FP32")
        self.model = SentenceTransformer(retriever_model, device='cuda')


        # Reranker
        print(f"✅ Loading reranker model [{reranker_model}] in FP32")
        self.reranker_model = CrossEncoder(reranker_model, device='cuda')

        self.batch_size = batch_size
        self.max_seq_length = max_seq_length
        self.use_pooling = use_pooling

        self.evidence_data = None
        self.claim_data = None
        self.evidence_embeddings = None
        self.claim_embeddings = None

        self.use_hard_negatives = True
        self.use_preprocessing = False
        self.normalize_embeddings = False
        self.reranking = True

        self.cache_dir = "embeddings_cache"
        # Create cache directory if it doesn't exist
        os.makedirs(self.cache_dir, exist_ok=True)

    def preprocess_text(self, text):
        # Lowercase
        text = text.lower().strip()

        # Remove HTML tags
        text = re.sub(r'<[^>]+>', '', text)

        # Remove punctuation
        text = re.sub(r'[^\w\s]', '', text)

        # Normalize whitespace
        text = ' '.join(text.split())

        # Remove stopwords
        stop_words = set(stopwords.words('english'))
        text = ' '.join([word for word in text.split() if word not in stop_words])

        # Lemmatization (preferred over stemming)
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

        return text

    def load_data(self, evidence_path, claim_path):
        print(f"Loading evidence data from {evidence_path}")
        with open(evidence_path, 'r') as f:
            self.evidence_data = json.load(f)

        print(f"Loading claim data from {claim_path}")
        with open(claim_path, 'r') as f:
            self.claim_data = json.load(f)

        if self.use_preprocessing:
            print("Preprocessing evidence and claim texts...")
            self.evidence_data = {eid: self.preprocess_text(text)
                                  for eid, text in self.evidence_data.items()}

            if "claim_text" in list(self.claim_data.values())[0]:
                for cid in self.claim_data:
                    self.claim_data[cid]["claim_text"] = self.preprocess_text(self.claim_data[cid]["claim_text"])
            else:
                self.claim_data = {cid: self.preprocess_text(text)
                                  for cid, text in self.claim_data.items()}

        print(f"Loaded {len(self.evidence_data)} evidence passages and {len(self.claim_data)} claims")
        return True

    def validate_loaded_data(self):
        """Validate that the loaded evidence and claims match expected counts and integrity."""
        # Check evidence data
        print(f"🔍 Validation Check: Loaded evidence passages = {len(self.evidence_data)}")
        if len(self.evidence_data) < 100000:
            print(f"⚠️ WARNING: Evidence passages seem unusually low ({len(self.evidence_data)}) compared to expected (~1,200,000). Check your loaded file or preprocessing.")

        # Check claims data
        print(f"🔍 Validation Check: Loaded claim samples = {len(self.claim_data)}")
        if len(self.claim_data) < 1000:
            print(f"⚠️ WARNING: Claim samples seem unusually low ({len(self.claim_data)}) compared to expected (~1,000). Check your loaded file or preprocessing.")

    def validate_before_embedding(self):
        """Validate before embedding begins."""
        print(f"🔍 Validation Check: About to embed {len(self.evidence_data)} evidence passages.")
        if len(self.evidence_data) < 100000:
            print(f"⚠️ WARNING: Embedding very few evidence passages ({len(self.evidence_data)}). This is likely wrong.")

    def _batch_encode(self, texts, desc):
        """Encode texts in batches efficiently"""
        embeddings = []
        for i in tqdm(range(0, len(texts), self.batch_size), desc=desc):
            batch_texts = texts[i:i + self.batch_size]
            if not batch_texts:
                continue
            # Stay in GPU, output as torch.Tensor
            batch_embeddings = self.model.encode(batch_texts, convert_to_tensor=True, device='cuda')

            # Normalize if enabled
            if self.normalize_embeddings:
                batch_embeddings = torch.nn.functional.normalize(batch_embeddings, p=2, dim=1)

            # Move to CPU only when saving or stacking
            embeddings.append(batch_embeddings.cpu())
        return torch.cat(embeddings, dim=0).numpy()

    def embed_evidence(self, save_path="evidence_embeddings_streamed.jsonl", mapping_save_path="evidence_id_mapping.json", overwrite=False):
        """
        Embed evidence texts and save with int ID mapping (required for FAISS).
        Also save the mapping to reverse back later.
        """
        print(f"📦 Streaming embeddings to {save_path}")
        if os.path.exists(save_path) and not overwrite:
            print("✅ Found cached evidence embeddings. Skipping embedding.")
            return

        self.validate_before_embedding()

        evidence_ids = list(self.evidence_data.keys())
        texts = list(self.evidence_data.values())

        id_mapping = {eid: idx for idx, eid in enumerate(evidence_ids)}  # string to int mapping

        with open(save_path, "w") as f:
            for i in tqdm(range(0, len(texts), self.batch_size), desc="Embedding evidence"):
                batch_ids = evidence_ids[i:i+self.batch_size]
                batch_texts = texts[i:i+self.batch_size]
                batch_embeds = self.model.encode(batch_texts, convert_to_tensor=True, device='cuda')
                if self.normalize_embeddings:
                    batch_embeds = torch.nn.functional.normalize(batch_embeds, p=2, dim=1)
                batch_embeds = batch_embeds.cpu().numpy()
                for eid, emb in zip(batch_ids, batch_embeds):
                    f.write(json.dumps({"id": id_mapping[eid], "original_id": eid, "embedding": emb.tolist()}) + "\n")

        with open(mapping_save_path, "w") as f:
            json.dump(id_mapping, f)

        print(f"✅ Done. Embeddings and mapping saved to {save_path} and {mapping_save_path}")

    def embed_claims(self, save_path=None, overwrite=False):
        """Embed claims, with caching for efficiency"""
        if save_path is None:
            save_path = os.path.join(self.cache_dir, f"claim_embeddings_{self.retriever_model.replace('/', '_')}.json")

        # Check if embeddings already exist
        if os.path.exists(save_path) and not overwrite:
            print(f"Loading pre-computed claim embeddings from {save_path}")
            with open(save_path, 'r') as f:
                embedding_dict = json.load(f)
                claim_ids = list(self.claim_data.keys())
                try:
                    self.claim_embeddings = np.array([embedding_dict[cid] for cid in claim_ids])
                    return self.claim_embeddings
                except:
                    print("Error loading cached embeddings. Recomputing...")

        # Embed claims
        claim_ids = list(self.claim_data.keys())

        # Extract claim text based on the format
        if isinstance(self.claim_data[claim_ids[0]], dict) and "claim_text" in self.claim_data[claim_ids[0]]:
            claim_texts = [self.claim_data[cid]["claim_text"] for cid in claim_ids]
        else:
            # For test-unlabelled
            claim_texts = [self.claim_data[cid] for cid in claim_ids]

        print(f"Embedding {len(claim_texts)} claims...")
        self.claim_embeddings = self._batch_encode(claim_texts, "Embedding claims")

        # Save embeddings
        embedding_dict = {cid: self.claim_embeddings[i].tolist() for i, cid in enumerate(claim_ids)}
        with open(save_path, 'w') as f:
            json.dump(embedding_dict, f)
            print(f"Saved claim embeddings to {save_path}")
        return self.claim_embeddings

    def fine_tune_model(self, epochs=1, learning_rate=2e-5):
        print("⚙️ Fine-tuning retriever model...")

        # Limit to 300 claims max
        subset_claims = dict(list(self.claim_data.items())[:300])
        all_evidence_ids = set(self.evidence_data.keys())

        train_examples = []
        for cid, claim in subset_claims.items():
            if "claim_text" not in claim or "evidences" not in claim:
                print(f"❌ Claim ID {cid} missing 'claim_text' or 'evidences'. Skipping.")
                continue

            claim_text = claim["claim_text"]
            positive_ids = claim["evidences"]

            for pid in positive_ids:
                if pid in self.evidence_data:
                    train_examples.append(InputExample(texts=[claim_text, self.evidence_data[pid]], label=1.0))

            # Sample 3 negatives
            negative_ids = list(all_evidence_ids - set(positive_ids))
            sampled_negs = random.sample(negative_ids, min(3, len(negative_ids)))
            for nid in sampled_negs:
                train_examples.append(InputExample(texts=[claim_text, self.evidence_data[nid]], label=0.0))

        train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=self.batch_size)
        train_loss = losses.MultipleNegativesRankingLoss(self.model)

        self.model.fit(
            train_objectives=[(train_dataloader, train_loss)],
            epochs=epochs,
            warmup_steps=100,
            show_progress_bar=True
        )

        print("✅ Fine-tuning complete.")

    @staticmethod
    def estimate_safe_buffer_size(claim_embeddings_shape, embedding_dim=768, safety_margin=0.7):
        """
        Estimate buffer size that safely fits in available VRAM together with claims.
        :param claim_embeddings_shape: shape of claim embeddings (num_claims, emb_dim)
        :param embedding_dim: dimension of embeddings (default 768)
        :param safety_margin: fraction of free VRAM to use (default 70%)
        :return: estimated safe buffer size
        """
        # Get free GPU memory in MB
        free_mem = torch.cuda.mem_get_info()[0] / (1024 ** 2)  # Free memory in MB
        target_mem = free_mem * safety_margin  # Use only safety_margin% of free VRAM

        # Estimate memory needed for claim embeddings (already loaded)
        num_claims = claim_embeddings_shape[0]
        claim_mem = num_claims * embedding_dim * 2 / (1024 ** 2)  # float16 (2 bytes per element)

        # Remaining memory for evidence buffer
        usable_mem = target_mem - claim_mem
        if usable_mem <= 0:
            print("❗ Warning: Not enough memory even for claims. Reduce batch size or use smaller model.")
            return 1000  # fallback small buffer

        # Calculate buffer size
        buffer_size = int((usable_mem * (1024 ** 2)) / (embedding_dim * 2))  # float16

        print(f"✅ Estimated safe buffer size: {buffer_size} (VRAM safety margin {safety_margin * 100:.0f}%)")
        return max(1000, buffer_size)

    def _process_buffer_gpu(self, buffer_ids, buffer_embs, claim_embs, results, k):
        # Load buffer to GPU in float16 for efficiency
        buffer_embs = torch.tensor(buffer_embs, dtype=torch.float16).cuda()

        if self.normalize_embeddings:
            buffer_embs = torch.nn.functional.normalize(buffer_embs, p=2, dim=1)

        sims = torch.matmul(claim_embs, buffer_embs.T)

        top_scores, top_indices = torch.topk(sims, k=k, dim=1)
        top_indices = top_indices.cpu().numpy()
        top_scores = top_scores.cpu().numpy()

        claim_keys = list(self.claim_data.keys())
        for i in trange(len(claim_keys), desc="🔄 Merging top-k per claim", leave=False, dynamic_ncols=True):
            cid = claim_keys[i]
            for idx, score in zip(top_indices[i], top_scores[i]):
                results[cid].append((buffer_ids[idx], float(score)))


    def retrieve_top_evidence(self, k=5, embedding_jsonl_path="evidence_embeddings_streamed.jsonl", buffer_size=None):
        if self.claim_embeddings is None:
            raise ValueError("Claim embeddings must be computed first")

        print(f"🔍 Streaming retrieval: Using GPU-accelerated cosine similarity")

        # Prepare claim embeddings on GPU (float16 for efficiency)
        claim_embs = torch.tensor(self.claim_embeddings, dtype=torch.float16).cuda()
        if self.normalize_embeddings:
            claim_embs = torch.nn.functional.normalize(claim_embs, p=2, dim=1)

        results = {cid: [] for cid in self.claim_data}

        # Estimate safe buffer size if not provided
        if buffer_size is None:
            buffer_size = self.estimate_safe_buffer_size(self.claim_embeddings.shape, embedding_dim=claim_embs.shape[1])

        total_lines = sum(1 for _ in open(embedding_jsonl_path))
        with open(embedding_jsonl_path, 'r') as f:
            buffer_ids = []
            buffer_embs = []

            for line in tqdm(f, desc="📥 Streaming evidence", total=total_lines, dynamic_ncols=True):
                obj = json.loads(line)
                buffer_ids.append(obj['original_id'])
                buffer_embs.append(obj['embedding'])

                if len(buffer_ids) >= buffer_size:
                    self._process_buffer_gpu(buffer_ids, buffer_embs, claim_embs, results, k)
                    buffer_ids, buffer_embs = [], []

            if buffer_ids:
                self._process_buffer_gpu(buffer_ids, buffer_embs, claim_embs, results, k)

        for cid in results:
            results[cid] = sorted(results[cid], key=lambda x: x[1], reverse=True)[:k]

        print("✅ Retrieval completed")
        return results

    def _rerank_results(self, initial_results, k=5):
        """Rerank initial results with Cross Encoder."""
        if not self.reranking:
            return initial_results

        print("Applying reranking to initial results (batched)...")
        reranked_results = {}

        batch_size = 16  # Safe default, adjust if OOM

        # Outer progress: per claim
        for claim_id, evidence_list in tqdm(initial_results.items(), desc="Claims reranking"):
            if not evidence_list:
                reranked_results[claim_id] = []
                continue

            claim_text = (
                self.claim_data[claim_id]["claim_text"]
                if isinstance(self.claim_data[claim_id], dict) and "claim_text" in self.claim_data[claim_id]
                else self.claim_data[claim_id]
            )

            evidence_pairs = [(claim_text, self.evidence_data[eid]) for eid, _ in evidence_list]

            rerank_scores = []
            # Inner progress: per batch within the claim
            for i in tqdm(range(0, len(evidence_pairs), batch_size), desc=f"Reranking {claim_id}", leave=False):
                batch_pairs = evidence_pairs[i:i + batch_size]
                rerank_scores.extend(self.reranker_model.predict(batch_pairs))

            reranked = sorted(
                zip(evidence_list, rerank_scores),
                key=lambda x: x[1],
                reverse=True
            )[:k]

            reranked_results[claim_id] = [(eid, float(score)) for ((eid, _), score) in reranked]

        return reranked_results

    def calculate_retrieval_metrics(self, results):
        """Calculate precision, recall, and F1 score for the retrieval results"""
        precisions = []
        recalls = []
        f1_scores = []

        for claim_id, retrieved_evidence in results.items():
          if not isinstance(self.claim_data[claim_id], dict) or 'evidences' not in self.claim_data[claim_id]:
              continue
          ground_truth = set(self.claim_data[claim_id]['evidences'])
          retrieved = set([ev_id for ev_id, _ in retrieved_evidence])
          true_positives = len(ground_truth.intersection(retrieved))
          precision = true_positives / len(retrieved) if len(retrieved) > 0 else 0
          recall = true_positives / len(ground_truth) if len(ground_truth) > 0 else 0
          f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
          precisions.append(precision)
          recalls.append(recall)
          f1_scores.append(f1)

        avg_precision = sum(precisions) / len(precisions) if precisions else 0
        avg_recall = sum(recalls) / len(recalls) if recalls else 0
        avg_f1 = sum(f1_scores) / len(f1_scores) if f1_scores else 0

        metrics = {
          "precision": avg_precision,
          "recall": avg_recall,
          "f1": avg_f1,
          "num_evaluated": len(precisions)
        }

        print(f"Evaluated on {metrics['num_evaluated']} claims")
        print(f"Average Precision: {metrics['precision']:.4f}")
        print(f"Average Recall: {metrics['recall']:.4f}")
        print(f"Average F1 Score: {metrics['f1']:.4f}")

        return metrics

    def run_pipeline(self, evidence_path, claim_path, k=5,
                     fine_tune=True, epochs=1,
                     evidence_save_path="evidence_embeddings_streamed.jsonl",
                     claim_save_path="claim_embeddings.json",
                     results_path="retrieval_results.json",
                     metrics_path="retrieval_metrics.json",
                     overwrite=False,
                     save_raw_embeddings=True):
        """
        A pipeline with checkpointing, memory-safe streaming, and auto-resume features.
        """
        print("🔁 Starting retrieval pipeline with checkpoints")

        # Step 1: Load data
        print("📥 Loading data...")
        self.load_data(evidence_path, claim_path)
        self.validate_loaded_data()

        # Step 2: Fine-tuning (optional)
        if fine_tune:
            if self.use_hard_negatives:
                print("🔐 Embedding evidence for hard negative mining...")
                self.embed_evidence(save_path=evidence_save_path)
            print("🧠 Fine-tuning model...")
            self.fine_tune_model(epochs=epochs)
        else:
            print("⚠️ Skipping fine-tuning")

        # Step 3: Embed evidence
        if not overwrite and os.path.exists(evidence_save_path):
            print(f"📦 Skipping evidence embedding. Using: {evidence_save_path}")
        else:
            print("📦 Embedding and saving evidence to JSONL...")
            self.embed_evidence(save_path=evidence_save_path, overwrite=overwrite)

        # 🆕 Save raw evidence embeddings to .npy
        if save_raw_embeddings:
            evidence_embs = []
            with open(evidence_save_path, 'r') as f:
                for line in f:
                    obj = json.loads(line)
                    evidence_embs.append(obj['embedding'])
            np.save("evidence_embeddings_raw.npy", np.array(evidence_embs, dtype=np.float32))
            print("✅ Saved raw evidence embeddings to evidence_embeddings_raw.npy")

        # Step 4: Embed claims
        if not overwrite and os.path.exists(claim_save_path):
            print(f"📦 Loading cached claim embeddings from {claim_save_path}")
            with open(claim_save_path) as f:
                loaded = json.load(f)
                self.claim_embeddings = np.array([loaded[cid] for cid in self.claim_data])
        else:
            print("📦 Embedding claims...")
            self.embed_claims(save_path=claim_save_path, overwrite=overwrite)

        # 🆕 Save raw claim embeddings to .npy
        if save_raw_embeddings:
            np.save("claim_embeddings_raw.npy", self.claim_embeddings)
            print("✅ Saved raw claim embeddings to claim_embeddings_raw.npy")

        # Step 5: Retrieval using streaming cosine similarity (no FAISS)
        if results_path and not overwrite and os.path.exists(results_path):
            print(f"📂 Loading existing retrieval results from {results_path}")
            with open(results_path, 'r') as f:
                results = json.load(f)
        else:
            print("🔍 Retrieving top-k evidence using cosine similarity and streaming...")
            results = self.retrieve_top_evidence(k=k, embedding_jsonl_path=evidence_save_path)
            if results_path:
                with open(results_path, 'w') as f:
                    json.dump(results, f)
                print(f"✅ Saved retrieval results to {results_path}")

        # Step 6: Evaluation
        print("📊 Evaluating retrieval...")
        metrics = self.calculate_retrieval_metrics(results)
        if metrics_path:
            with open(metrics_path, 'w') as f:
                json.dump(metrics, f)
            print(f"✅ Saved metrics to {metrics_path}")

        return results, metrics



    def format_evidences(self,evidence_ids, evidence_dict):
        return '\n'.join([f"{i+1}. {evidence_dict.get(eid, '[MISSING]')}" for i, eid in enumerate(evidence_ids)])

    def build_prompt_cot(self, test_claim, evidence_dict):

        # 1) Header (triple-quoted, same style as before)
        header = """
        Please analyze the relationship between evidence and claim based on the following four examples, each of which shows a chain of thought. Think step by step, writing out your full reasoning and then classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """

        # 2) Four CoT examples (triple-quoted, numbered as before)
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        - At very high concentrations (100× atmospheric), CO2 is toxic to animals.
        - Plants grow up to 50% faster at 1,000 ppm CO₂ under unlimited nutrients.
        - Higher CO₂ also alters water demand and can create ecological imbalances.
        Reasoning:
        1. CO₂ has both positive (plant growth) and negative (toxicity, water‐stress) effects.
        2. The net ecological impact is therefore debated and not uniformly beneficial.
        Label: DISPUTED

        Example2：
        Claim: El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        - El Niño causes short-term warming spikes.
        - Long-term temperature trends correlate with rising greenhouse gas levels, not El Niño cycles.
        Reasoning:
        1. El Niño is a transient phenomenon, not a sustained climate forcing.
        2. Evidence attributes persistent warming to human CO₂ emissions.
        3. Therefore, attributing record highs solely to El Niño is incorrect.
        Label: REFUTES

        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        - The PDO shifted to a cool phase in 1945/1946, as recorded by ocean temperature patterns.
        - Historical regime shifts around 1947 match salmon production changes in the North Pacific.
        Reasoning:
        1. Oceanographic data confirm a cool-phase shift around 1946.
        2. Independent ecological records (salmon regimes) align with that timing.
        3. Thus, the claim is supported by multiple lines of evidence.
        Label: SUPPORTS

        Example4：
        Claim: Climate scientists have predicted global temperatures would increase more than one degree Celsius by 2020, but observed temperatures have been only half as high.
        Evidences:
        - In February 2020 the region recorded 18.3 °C, about 0.83 °C above 1880 levels.
        - The last century saw an average rise of ~0.8 °C, most of it in the last three decades.
        - Projections for 2100 anticipate up to +4 °C if emissions remain unchecked.
        Reasoning:
        1. Observed warming (~0.8 °C) matches projections within expected uncertainty.
        2. Regional short-term records do not contradict global model forecasts.
        3. The evidence does not clearly show a two-fold overprediction by models.
        Label: NOT_ENOUGH_INFO
        """

        # 3) Prepare the test claim block, same "Now classify:" style
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim['claim_text']}
        Evidences:
        {test_evi}
        Reasoning:
        Label:"""

        return header + examples + test_input
    def build_prompt_5example_cot(self, test_claim, evidence_dict):

        # 1) Header (triple-quoted, same style as before)
        header = """
        Please analyze the relationship between evidence and claim based on the following four examples, each of which shows a chain of thought. Think step by step, writing out your full reasoning and then classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """

        # 2) Four CoT examples (triple-quoted, numbered as before)
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        - At very high concentrations (100× atmospheric), CO2 is toxic to animals.
        - Plants grow up to 50% faster at 1,000 ppm CO₂ under unlimited nutrients.
        - Higher CO₂ also alters water demand and can create ecological imbalances.
        Reasoning:
        1. CO₂ has both positive (plant growth) and negative (toxicity, water‐stress) effects.
        2. The net ecological impact is therefore debated and not uniformly beneficial.
        Label: DISPUTED

        Example2：
        Claim: El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        - El Niño causes short-term warming spikes.
        - Long-term temperature trends correlate with rising greenhouse gas levels, not El Niño cycles.
        Reasoning:
        1. El Niño is a transient phenomenon, not a sustained climate forcing.
        2. Evidence attributes persistent warming to human CO₂ emissions.
        3. Therefore, attributing record highs solely to El Niño is incorrect.
        Label: REFUTES

        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        - The PDO shifted to a cool phase in 1945/1946, as recorded by ocean temperature patterns.
        - Historical regime shifts around 1947 match salmon production changes in the North Pacific.
        Reasoning:
        1. Oceanographic data confirm a cool-phase shift around 1946.
        2. Independent ecological records (salmon regimes) align with that timing.
        3. Thus, the claim is supported by multiple lines of evidence.
        Label: SUPPORTS

        Example4：
        Claim: Climate scientists have predicted global temperatures would increase more than one degree Celsius by 2020, but observed temperatures have been only half as high.
        Evidences:
        - In February 2020 the region recorded 18.3 °C, about 0.83 °C above 1880 levels.
        - The last century saw an average rise of ~0.8 °C, most of it in the last three decades.
        - Projections for 2100 anticipate up to +4 °C if emissions remain unchecked.
        Reasoning:
        1. Observed warming (~0.8 °C) matches projections within expected uncertainty.
        2. Regional short-term records do not contradict global model forecasts.
        3. The evidence does not clearly show a two-fold overprediction by models.
        Label: NOT_ENOUGH_INFO

        Example 5：
        Claim: When stomata-derived CO₂ (red) is compared to ice-core-derived CO₂ (blue), the stomata generally show much more variability in the atmospheric CO₂ level and often show levels much higher than the ice cores.
        Evidences:
        - One study using stomata on fossilized leaves reports CO₂ mole fractions above 300 ppm between seven and ten thousand years ago, suggesting greater variability.
        - Other researchers argue these high stomatal values likely stem from calibration or contamination issues rather than true atmospheric fluctuations.
        Reasoning:
        1. The stomatal evidence shows peaks (>300 ppm) not matched by ice-core records, indicating higher measured variability.
        2. While calibration/contamination could inflate some values, the repeated pattern across samples suggests a real effect.
        3. Therefore, even allowing for potential errors, the stomatal data support the claim of greater CO₂ variability than ice cores indicate.
        Answer: SUPPORTS
        """

        # 3) Prepare the test claim block, same "Now classify:" style
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim['claim_text']}
        Evidences:
        {test_evi}
        Reasoning:
        Label:"""

        return header + examples + test_input
    def build_prompt_3example_cot(self,test_claim, evidence_dict):
        header = """
        Please analyze the relationship between evidence and claim based on the following four examples, each of which shows a chain of thought. Think step by step, writing out your full reasoning and then classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        - At very high concentrations (100× atmospheric), CO2 is toxic to animals.
        - Plants grow up to 50% faster at 1,000 ppm CO₂ under unlimited nutrients.
        - Higher CO₂ also alters water demand and can create ecological imbalances.
        Reasoning:
        1. CO₂ has both positive (plant growth) and negative (toxicity, water‐stress) effects.
        2. The net ecological impact is therefore debated and not uniformly beneficial.
        Label: DISPUTED

        Example2：
        Claim: El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        - El Niño causes short-term warming spikes.
        - Long-term temperature trends correlate with rising greenhouse gas levels, not El Niño cycles.
        Reasoning:
        1. El Niño is a transient phenomenon, not a sustained climate forcing.
        2. Evidence attributes persistent warming to human CO₂ emissions.
        3. Therefore, attributing record highs solely to El Niño is incorrect.
        Label: REFUTES

        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        - The PDO shifted to a cool phase in 1945/1946, as recorded by ocean temperature patterns.
        - Historical regime shifts around 1947 match salmon production changes in the North Pacific.
        Reasoning:
        1. Oceanographic data confirm a cool-phase shift around 1946.
        2. Independent ecological records (salmon regimes) align with that timing.
        3. Thus, the claim is supported by multiple lines of evidence.
        Label: SUPPORTS
        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim['claim_text']}
        Evidences:
        {test_evi}
        Reasoning:
        Label:"""

        return header + examples + test_input
    def build_prompt_2example_cot(self,test_claim, evidence_dict):
        header = """
        Please analyze the relationship between evidence and claim based on the following four examples, each of which shows a chain of thought. Think step by step, writing out your full reasoning and then classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        - At very high concentrations (100× atmospheric), CO2 is toxic to animals.
        - Plants grow up to 50% faster at 1,000 ppm CO₂ under unlimited nutrients.
        - Higher CO₂ also alters water demand and can create ecological imbalances.
        Reasoning:
        1. CO₂ has both positive (plant growth) and negative (toxicity, water‐stress) effects.
        2. The net ecological impact is therefore debated and not uniformly beneficial.
        Label: DISPUTED

        Example2：
        Claim: El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        - El Niño causes short-term warming spikes.
        - Long-term temperature trends correlate with rising greenhouse gas levels, not El Niño cycles.
        Reasoning:
        1. El Niño is a transient phenomenon, not a sustained climate forcing.
        2. Evidence attributes persistent warming to human CO₂ emissions.
        3. Therefore, attributing record highs solely to El Niño is incorrect.
        Label: REFUTES
        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim['claim_text']}
        Evidences:
        {test_evi}
        Reasoning:
        Label:"""

        return header + examples + test_input
    def build_prompt_1example_cot(self,test_claim, evidence_dict):
        header = """
        Please analyze the relationship between evidence and claim based on the following four examples, each of which shows a chain of thought. Think step by step, writing out your full reasoning and then classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        - At very high concentrations (100× atmospheric), CO2 is toxic to animals.
        - Plants grow up to 50% faster at 1,000 ppm CO₂ under unlimited nutrients.
        - Higher CO₂ also alters water demand and can create ecological imbalances.
        Reasoning:
        1. CO₂ has both positive (plant growth) and negative (toxicity, water‐stress) effects.
        2. The net ecological impact is therefore debated and not uniformly beneficial.
        Label: DISPUTED

        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim['claim_text']}
        Evidences:
        {test_evi}
        Reasoning:
        Label:"""

        return header + examples + test_input
    def build_prompt(self,test_claim, evidence_dict):
        header = """Please analyze the relationship between evidence and claim based on the following four examples. classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        At very high concentrations (100 times atmospheric concentration, or greater), carbon dioxide can be toxic to animal life, so raising the concentration to 10,000 ppm (1%) or higher for several hours will eliminate pests such as whiteflies and spider mites in a greenhouse.
        Plants can grow as much as 50 percent faster in concentrations of 1,000 ppm CO 2 when compared with ambient conditions, though this assumes no change in climate and no limitation on other nutrients.
        Higher carbon dioxide concentrations will favourably affect plant growth and demand for water.
        Label: DISPUTED
        Example2：
        Claim: El Ni\u00f1o drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        While ‘climate change’ can be due to natural forces or human activity, there is now substantial evidence to indicate that human activity – and specifically increased greenhouse gas (GHGs) emissions – is a key factor in the pace and extent of global temperature increases.
        This acceleration is due mostly to human-caused global warming, which is driving thermal expansion of seawater and the melting of land-based ice sheets and glaciers.
        Label: REFUTES
        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        There is evidence of reversals in the prevailing polarity (meaning changes in cool surface waters versus warm surface waters within the region) of the oscillation occurring around 1925, 1947, and 1977; the last two reversals corresponded with dramatic shifts in salmon production regimes in the North Pacific Ocean.
        1945/1946: The PDO changed to a "cool" phase, the pattern of this regime shift is similar to the 1970s episode with maximum amplitude in the subarctic and subtropical front but with a greater signature near the Japan while the 1970s shift was stronger near the American west coast.
        Label: SUPPORTS
        Example4：
        Claim: Climate scientists have predicted global temperatures would increase more than one degree Celsius by 2020,\" but observed temperatures have been only half as high.
        Evidences:
        In February 2020, the region recorded the highest temperature of 18.3 degree Celsius which was a degree higher than the previous record of 17.5 degrees in March 2015.
        The Earth's average surface temperature has increased by 1.5 °F (0.83 °C) since 1880.
        About a billion years from now, all surface water will have disappeared and the mean global temperature will reach 70 °C (158 °F).
        In the last 100 years, Earth's average surface temperature increased by about 0.8 °C (1.4 °F) with about two thirds of the increase occurring over just the last three decades.
        The 10th Emissions Gap Report issued by the United Nations Environment Programme (UNEP) predicts that if emissions continue to increase at the same rate as they have in 2010–2020, global temperatures would rise by as much as 4° by 2100.
        Label: NOT_ENOUGH_INFO
        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim["claim_text"]}
        Evidences:
        {test_evi}
        Label:"""
        return header + examples + test_input

    def build_prompt_1example(self,test_claim, evidence_dict):
        header = """Please analyze the relationship between evidence and claim based on the following one examples. classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        At very high concentrations (100 times atmospheric concentration, or greater), carbon dioxide can be toxic to animal life, so raising the concentration to 10,000 ppm (1%) or higher for several hours will eliminate pests such as whiteflies and spider mites in a greenhouse.
        Plants can grow as much as 50 percent faster in concentrations of 1,000 ppm CO 2 when compared with ambient conditions, though this assumes no change in climate and no limitation on other nutrients.
        Higher carbon dioxide concentrations will favourably affect plant growth and demand for water.
        Label: DISPUTED

        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim["claim_text"]}
        Evidences:
        {test_evi}
        Label:"""
        return header + examples + test_input

    def build_prompt_2example(self,test_claim, evidence_dict):
        header = """Please analyze the relationship between evidence and claim based on the following two examples. classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        At very high concentrations (100 times atmospheric concentration, or greater), carbon dioxide can be toxic to animal life, so raising the concentration to 10,000 ppm (1%) or higher for several hours will eliminate pests such as whiteflies and spider mites in a greenhouse.
        Plants can grow as much as 50 percent faster in concentrations of 1,000 ppm CO 2 when compared with ambient conditions, though this assumes no change in climate and no limitation on other nutrients.
        Higher carbon dioxide concentrations will favourably affect plant growth and demand for water.
        Label: DISPUTED
        Example2：
        Claim: El Ni\u00f1o drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        While ‘climate change’ can be due to natural forces or human activity, there is now substantial evidence to indicate that human activity – and specifically increased greenhouse gas (GHGs) emissions – is a key factor in the pace and extent of global temperature increases.
        This acceleration is due mostly to human-caused global warming, which is driving thermal expansion of seawater and the melting of land-based ice sheets and glaciers.
        Label: REFUTES

        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim["claim_text"]}
        Evidences:
        {test_evi}
        Label:"""
        return header + examples + test_input


    def build_prompt_3example(self,test_claim, evidence_dict):
        header = """Please analyze the relationship between evidence and claim based on the following three examples. classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        At very high concentrations (100 times atmospheric concentration, or greater), carbon dioxide can be toxic to animal life, so raising the concentration to 10,000 ppm (1%) or higher for several hours will eliminate pests such as whiteflies and spider mites in a greenhouse.
        Plants can grow as much as 50 percent faster in concentrations of 1,000 ppm CO 2 when compared with ambient conditions, though this assumes no change in climate and no limitation on other nutrients.
        Higher carbon dioxide concentrations will favourably affect plant growth and demand for water.
        Label: DISPUTED
        Example2：
        Claim: El Ni\u00f1o drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        While ‘climate change’ can be due to natural forces or human activity, there is now substantial evidence to indicate that human activity – and specifically increased greenhouse gas (GHGs) emissions – is a key factor in the pace and extent of global temperature increases.
        This acceleration is due mostly to human-caused global warming, which is driving thermal expansion of seawater and the melting of land-based ice sheets and glaciers.
        Label: REFUTES
        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        There is evidence of reversals in the prevailing polarity (meaning changes in cool surface waters versus warm surface waters within the region) of the oscillation occurring around 1925, 1947, and 1977; the last two reversals corresponded with dramatic shifts in salmon production regimes in the North Pacific Ocean.
        1945/1946: The PDO changed to a "cool" phase, the pattern of this regime shift is similar to the 1970s episode with maximum amplitude in the subarctic and subtropical front but with a greater signature near the Japan while the 1970s shift was stronger near the American west coast.
        Label: SUPPORTS

        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim["claim_text"]}
        Evidences:
        {test_evi}
        Label:"""
        return header + examples + test_input


    def build_prompt_5example(self,test_claim, evidence_dict):
        header = """Please analyze the relationship between evidence and claim based on the following five examples. classify the relationship as one of:
        - SUPPORTS
        - REFUTES
        - NOT ENOUGH INFO
        - DISPUTED
        """
        examples = """
        Example1：
        Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
        Evidences:
        At very high concentrations (100 times atmospheric concentration, or greater), carbon dioxide can be toxic to animal life, so raising the concentration to 10,000 ppm (1%) or higher for several hours will eliminate pests such as whiteflies and spider mites in a greenhouse.
        Plants can grow as much as 50 percent faster in concentrations of 1,000 ppm CO 2 when compared with ambient conditions, though this assumes no change in climate and no limitation on other nutrients.
        Higher carbon dioxide concentrations will favourably affect plant growth and demand for water.
        Label: DISPUTED
        Example2：
        Claim: El Ni\u00f1o drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
        Evidences:
        While ‘climate change’ can be due to natural forces or human activity, there is now substantial evidence to indicate that human activity – and specifically increased greenhouse gas (GHGs) emissions – is a key factor in the pace and extent of global temperature increases.
        This acceleration is due mostly to human-caused global warming, which is driving thermal expansion of seawater and the melting of land-based ice sheets and glaciers.
        Label: REFUTES
        Example3：
        Claim: In 1946, PDO switched to a cool phase.
        Evidences:
        There is evidence of reversals in the prevailing polarity (meaning changes in cool surface waters versus warm surface waters within the region) of the oscillation occurring around 1925, 1947, and 1977; the last two reversals corresponded with dramatic shifts in salmon production regimes in the North Pacific Ocean.
        1945/1946: The PDO changed to a "cool" phase, the pattern of this regime shift is similar to the 1970s episode with maximum amplitude in the subarctic and subtropical front but with a greater signature near the Japan while the 1970s shift was stronger near the American west coast.
        Label: SUPPORTS
        Example4：
        Claim: Climate scientists have predicted global temperatures would increase more than one degree Celsius by 2020,\" but observed temperatures have been only half as high.
        Evidences:
        In February 2020, the region recorded the highest temperature of 18.3 degree Celsius which was a degree higher than the previous record of 17.5 degrees in March 2015.
        The Earth's average surface temperature has increased by 1.5 °F (0.83 °C) since 1880.
        About a billion years from now, all surface water will have disappeared and the mean global temperature will reach 70 °C (158 °F).
        In the last 100 years, Earth's average surface temperature increased by about 0.8 °C (1.4 °F) with about two thirds of the increase occurring over just the last three decades.
        The 10th Emissions Gap Report issued by the United Nations Environment Programme (UNEP) predicts that if emissions continue to increase at the same rate as they have in 2010–2020, global temperatures would rise by as much as 4° by 2100.
        Label: NOT_ENOUGH_INFO
        Example5：
        Claim: When stomata-derived CO2 (red) is compared to ice core-derived CO2 (blue), the stomata generally show much more variability in the atmospheric CO2 level and often show levels much higher than the ice cores.
        Evidences: One study using evidence from stomata of fossilized leaves suggests greater variability, with carbon dioxide mole fractions above 300 ppm during the period seven to ten thousand years ago, though others have argued that these findings more likely reflect calibration or contamination problems rather than actual CO 2 variability.
        Label: SUPPORTS
        """
        test_evi = self.format_evidences(test_claim["evidences"], evidence_dict)
        test_input = f"""
        Now classify:
        Claim: {test_claim["claim_text"]}
        Evidences:
        {test_evi}
        Label:"""
        return header + examples + test_input

    def get_predictions_with_ids_cot(self, claim_items, evidence_dict, model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0", max_new_tokens= 20, example_n=4):
        predictions = {}
        actuals = {}
        final_results = {}
        if not hasattr(self, 'llama_tokenizer'):
            self.llama_tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
            self.llama_model     = AutoModelForCausalLM.from_pretrained(
                model_name,
                torch_dtype=torch.float16,
                device_map="auto"
            )
            self.llama_model.eval()

        for claim_id, test_claim in claim_items:
          if example_n == 4:
            prompt = self.build_prompt_cot(test_claim, evidence_dict)
          elif example_n == 2:
            prompt = self.build_prompt_2example_cot(test_claim, evidence_dict)
          elif example_n == 3:
            prompt = self.build_prompt_3example_cot(test_claim, evidence_dict)
          elif example_n == 5:
            prompt = self.build_prompt_5example_cot(test_claim, evidence_dict)
          elif example_n == 1:
            prompt = self.build_prompt_1example_cot(test_claim, evidence_dict)
          # prompt = self.build_prompt(test_claim, evidence_dict)
          inputs = self.llama_tokenizer(prompt, return_tensors="pt").to(self.llama_model.device)
          with torch.no_grad():
              outputs = self.llama_model.generate(
                  **inputs,
                  max_new_tokens=max_new_tokens,
                  do_sample=False
              )
          decoded = self.llama_tokenizer.decode(outputs[0], skip_special_tokens=True)

          # 4.6 Extract the label from the generated text
          prediction = decoded.split("Label:")[-1].strip().split()[0].upper()


          actual = test_claim["claim_label"].upper()

          predictions[claim_id] = prediction
          actuals[claim_id] = actual

          print(f"Claim ID: {claim_id}")
          print(f"Claim: {test_claim['claim_text']}")
          print(f"Predicted: {prediction}, Actual: {actual}\n")

          final_results[claim_id] = {
                "claim_label": prediction,
                "evidences": test_claim['evidences']
          }

        return final_results, predictions, actuals

    def classify_with_cot(self, example_n = 4, model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0", input_path = "/content/drive/MyDrive/predictions_retriever20_reranker3_3.json"):

        with open(input_path, "r") as f:
          classify_claims = json.load(f)

        classify_claims_ids = list(classify_claims.keys())
        classify_claims_texts = [classify_claims[cid]['claim_text'] for cid in classify_claims_ids]
        final_results, predictions, actuals = self.get_predictions_with_ids_cot(claim_items=list(classify_claims.items()), evidence_dict=self.evidence_data, model_name=model_name,max_new_tokens=20, example_n=example_n)
        return final_results

    def classify_with_fix_examples(self, example_n = 4, model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0", input_path = "/content/drive/MyDrive/predictions_retriever20_reranker3_3.json"):

        with open(input_path, "r") as f:
          classify_claims = json.load(f)

        classify_claims_ids = list(classify_claims.keys())
        classify_claims_texts = [classify_claims[cid]['claim_text'] for cid in classify_claims_ids]
        final_results, predictions, actuals = self.get_predictions_with_ids(claim_items=list(classify_claims.items()), evidence_dict=self.evidence_data, model_name=model_name,max_new_tokens=20, example_n=example_n)
        return final_results

    def get_predictions_with_ids(self, claim_items, evidence_dict, model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0", max_new_tokens= 20, example_n=4):
        predictions = {}
        actuals = {}
        final_results = {}
        if not hasattr(self, 'llama_tokenizer'):
            self.llama_tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
            self.llama_model     = AutoModelForCausalLM.from_pretrained(
                model_name,
                torch_dtype=torch.float16,
                device_map="auto"
            )
            self.llama_model.eval()

        for claim_id, test_claim in claim_items:
          if example_n == 4:
            prompt = self.build_prompt(test_claim, evidence_dict)
          elif example_n == 2:
            prompt = self.build_prompt_2example(test_claim, evidence_dict)
          elif example_n == 3:
            prompt = self.build_prompt_3example(test_claim, evidence_dict)
          elif example_n == 5:
            prompt = self.build_prompt_5example(test_claim, evidence_dict)
          elif example_n == 1:
            prompt = self.build_prompt_1example(test_claim, evidence_dict)
          # prompt = self.build_prompt(test_claim, evidence_dict)
          inputs = self.llama_tokenizer(prompt, return_tensors="pt").to(self.llama_model.device)
          with torch.no_grad():
              outputs = self.llama_model.generate(
                  **inputs,
                  max_new_tokens=max_new_tokens,
                  do_sample=False
              )
          decoded = self.llama_tokenizer.decode(outputs[0], skip_special_tokens=True)

          # 4.6 Extract the label from the generated text
          prediction = decoded.split("Label:")[-1].strip().split()[0].upper()


          actual = test_claim["claim_label"].upper()

          predictions[claim_id] = prediction
          actuals[claim_id] = actual

          print(f"Claim ID: {claim_id}")
          print(f"Claim: {test_claim['claim_text']}")
          print(f"Predicted: {prediction}, Actual: {actual}\n")

          final_results[claim_id] = {
                "claim_label": prediction,
                "evidences": test_claim['evidences']
          }

        return final_results, predictions, actuals




    def classify_with_local_llm(self,
                              predictions_path: str,
                              output_path: str,
                              num_shot: int = 5,
                              model_name: str = "TinyLlama/TinyLlama-1.1B-Chat-v1.0",
                              max_new_tokens: int = 20):
        """
        Perform few-shot classification of previously retrieved predictions
        using a local TinyLLaMA model, with progress reporting.

        :param predictions_path: Path to a JSON file mapping claim_id -> {"evidences": [...]}
        :param output_path:       Destination JSON path for final labels + evidences
        :param num_shot:          Number of few-shot examples to include
        :param model_name:        HuggingFace identifier for the TinyLLaMA model
        :param max_new_tokens:    Maximum tokens to generate for each answer
        """

        # 1) Load the labeled training claims for few-shot examples
        if not hasattr(self, 'train_claims'):
            with open(TRAIN_CLAIMS_PATH, 'r', encoding='utf-8') as f:
                self.train_claims = json.load(f)
            self.train_ids   = list(self.train_claims.keys())
            self.train_texts = [self.train_claims[cid]['claim_text'] for cid in self.train_ids]
            self.train_embs  = self.model.encode(self.train_texts, convert_to_tensor=False)

        # 2) Load the local TinyLLaMA tokenizer & model
        if not hasattr(self, 'llama_tokenizer'):
            self.llama_tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
            self.llama_model     = AutoModelForCausalLM.from_pretrained(
                model_name,
                torch_dtype=torch.float16,
                device_map="auto"
            )
            self.llama_model.eval()

        # 3) Read the previously saved predictions (claim_id -> evidences)
        with open(predictions_path, 'r', encoding='utf-8') as f:
            preds = json.load(f)

        total = len(preds)
        print(f"🔄 Starting classification of {total} claims with TinyLLaMA…")

        final_results = {}

        # 4) Loop over each claim with progress updates
        for idx, (cid, entry) in enumerate(preds.items(), start=1):
            # if idx == 40:
            #   break
            if idx == 1 or idx % 20 == 0 or idx == total:
                print(f"  → Progress: {idx}/{total} (claim_id={cid})")

            # 4.1 Retrieve the claim text
            raw = self.claim_data[cid]
            claim_text = raw['claim_text'] if isinstance(raw, dict) else raw

            # 4.2 Retrieve the top-k evidence texts
            ev_texts = [self.evidence_data[eid] for eid in entry['evidences']]

            # 4.3 Select few-shot examples by embedding similarity
            target_emb = self.model.encode([claim_text], convert_to_tensor=False)[0]
            sims       = cosine_similarity([target_emb], self.train_embs)[0]
            chosen_idxs = np.argsort(sims)[-num_shot:][::-1]

            examples = []
            for i in chosen_idxs:
                tcid   = self.train_ids[i]
                tclaim = self.train_claims[tcid]['claim_text']
                teids  = self.train_claims[tcid]['evidences']
                tlabel = self.train_claims[tcid].get('claim_label', 'NOT_ENOUGH_INFO')
                evs    = [self.evidence_data[eid] for eid in teids]
                examples.append({'claim': tclaim, 'evidences': evs, 'label': tlabel})

            # 4.4 Build the few-shot prompt
            prompt = (
                "You are an expert fact-checker.\n"
                "For each claim below, assess how relevant and valid each evidence snippet is, "
                "and then respond with exactly one of the following labels:\n"
                "  SUPPORTS, REFUTES, NOT_ENOUGH_INFO, or DISPUTED.\n\n"
            )
            for ex in examples:
                prompt += f"Q: {ex['claim']}\n"
                prompt += "Evidence:\n" + "\n".join(f"- {s}" for s in ex['evidences']) + "\n"
                prompt += f"A: {ex['label']}\n\n"

            prompt += f"Q: {claim_text}\n"
            prompt += "Evidence:\n" + "\n".join(f"- {s}" for s in ev_texts) + "\nA:"

            # 4.5 Generate the answer (greedy decoding)
            inputs = self.llama_tokenizer(prompt, return_tensors="pt").to(self.llama_model.device)
            with torch.no_grad():
                outputs = self.llama_model.generate(
                    **inputs,
                    max_new_tokens=max_new_tokens,
                    do_sample=False
                )
            decoded = self.llama_tokenizer.decode(outputs[0], skip_special_tokens=True)

            # 4.6 Extract the label from the generated text
            label = decoded.split("A:")[-1].strip().split()[0].upper()
            if label not in ["SUPPORTS", "REFUTES", "NOT_ENOUGH_INFO", "DISPUTED"]:
                label = "NOT_ENOUGH_INFO"

            final_results[cid] = {
                "claim_label": label,
                "evidences": entry['evidences']
            }

        # 5) Write the final results to JSON
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(final_results, f, indent=2, ensure_ascii=False)

        print(f"✅ Done! Processed {total} claims. Results saved to {output_path}")
        return final_results



    def classify_with_few_shot_new(self, ranked_result, k=3, num_shot=5, model_name="TinyLlama/TinyLlama-1.1B-Chat-v1.0", temperature=0.0,max_new_tokens = 20):
        """
        Few-shot in-context classification using top-k evidence and Chain-of-Thought prompting.
        """
        import openai

        # 1. Load and embed training claims if not already loaded
        if not hasattr(self, 'train_claims'):
            with open(TRAIN_CLAIMS_PATH, 'r') as f:
                self.train_claims = json.load(f)
            self.train_ids = list(self.train_claims.keys())
            self.train_texts = [self.train_claims[cid]['claim_text'] for cid in self.train_ids]
            self.train_embs = self.model.encode(self.train_texts)

        if not hasattr(self, 'llama_tokenizer'):
            self.llama_tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
            self.llama_model     = AutoModelForCausalLM.from_pretrained(
                model_name,
                torch_dtype=torch.float16,
                device_map="auto"
            )
            self.llama_model.eval()

        # 2. Retrieve top-k evidence for all claims
        topk = ranked_result

        results = {}
        for cid, candidates in topk.items():
            # Claim text and evidence
            raw = self.claim_data[cid]
            claim_text = raw['claim_text'] if isinstance(raw, dict) else raw
            ev_ids = [eid for eid in candidates['evidences']]
            ev_texts = [self.evidence_data[eid] for eid in ev_ids]

            # Auto-select few-shot examples by similarity
            target_emb = self.model.encode([claim_text])[0]
            sims = cosine_similarity([target_emb], self.train_embs)[0]
            idx = np.argsort(sims)[-num_shot:][::-1]
            examples = []
            for i in idx:
                tcid = self.train_ids[i]
                tclaim = self.train_claims[tcid]['claim_text']
                teids = self.train_claims[tcid]['evidences']
                tlabel = self.train_claims[tcid]['claim_label']
                examples.append({'claim': tclaim, 'evidences': teids, 'label': tlabel})

            # Build CoT-style few-shot prompt
            prompt = (
                "You are an expert fact-checker. Given a claim and its supporting evidence passages, think carefully step by step and determine whether the claim is one of: SUPPORTS, REFUTES, NOT_ENOUGH_INFO, or DISPUTED.\n\n"
            )
            for ex in examples:
                txts = [self.evidence_data[eid] for eid in ex['evidences']]
                prompt += f"Claim: {ex['claim']}\n"
                prompt += f"Evidence: {' '.join(txts)}\n"
                prompt += "Let's think step by step:\n"
                prompt += f"- Review the evidence carefully.\n"
                prompt += f"- Identify if the evidence directly supports, refutes, provides insufficient information, or shows conflicting information.\n"
                prompt += f"- Conclusion: {ex['label']}\n\n"
            prompt += f"Claim: {claim_text}\n"
            prompt += f"Evidence: {' '.join(ev_texts)}\n"
            prompt += "Let's think step by step:\n"

            # 4.6 Extract the label from the generated text
            inputs = self.llama_tokenizer(prompt, return_tensors="pt").to(self.llama_model.device)
            with torch.no_grad():
                outputs = self.llama_model.generate(
                    **inputs,
                    max_new_tokens=max_new_tokens,
                    do_sample=False
                )
            decoded = self.llama_tokenizer.decode(outputs[0], skip_special_tokens=True)
            # label = decoded[len(prompt):].strip()
            # decoded = self.llama_tokenizer.decode(outputs[0], skip_special_tokens=True)
            # last_output = decoded[len(prompt):].strip()
            # label = last_output.split("\n")[0].split()[0].upper()]
            import re
            matches = re.findall(r"Conclusion:\s*(SUPPORTS|REFUTES|NOT_ENOUGH_INFO|DISPUTED)", decoded)
            if matches:
                label = matches[-1]
            else:
                label = 'SUPPORTS'



            # Format result
            results[cid] = {
                # 'claim_text': claim_text,
                'claim_label': label,
                'evidences': ev_ids
            }

        return results




    def weighted_majority_vote(self, pred_dicts, weights):
        """
        pred_dicts: list of dicts containing claim -> {claim_label, evidences}
        weights: list of floats corresponding to each dict
        Returns: dict of claim -> {claim_label, evidences}
        """
        assert len(pred_dicts) == len(weights), "Each prediction dict must have a corresponding weight."

        claim_label_scores = defaultdict(lambda: defaultdict(float))  # claim -> label -> total_weight
        claim_label_evidences = defaultdict(lambda: defaultdict(list))  # claim -> label -> [evidences]

        # Count votes and track evidence per label
        for pred_dict, weight in zip(pred_dicts, weights):
            for claim_id, data in pred_dict.items():
                label = data['claim_label']
                evidences = data['evidences']
                claim_label_scores[claim_id][label] += weight
                claim_label_evidences[claim_id][label].append(evidences)

        # Build final result
        final_result = {}
        for claim_id, label_scores in claim_label_scores.items():
            # Choose the label with highest weight
            final_label = max(label_scores.items(), key=lambda x: x[1])[0]
            # Pick the first evidences list from the winning label's votes
            final_evidences = claim_label_evidences[claim_id][final_label][0]
            final_result[claim_id] = {
                'claim_label': final_label,
                'evidences': final_evidences
            }

        return final_result


    def combine_method(self, predictions_path = "/content/drive/MyDrive/predictions_retriever20_reranker3_2.json", output_path = '/content/drive/MyDrive/outout1.json', model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0", weights = [0.4,0.3,0.3]):
        with open(predictions_path, "r") as f:
          classify_claims = json.load(f)
        print('first model')
        final_result1 = self.classify_with_local_llm(num_shot=3,model_name = model_name,predictions_path = predictions_path,output_path=output_path)
        print('second model')
        final_result2 = self.classify_with_cot(example_n = 3, model_name = model_name, input_path = predictions_path)
        print('third model')
        final_result3 = self.classify_with_fix_examples(example_n = 3, model_name = model_name, input_path = predictions_path)
        print('finish, start combine')
        pred_dicts = [final_result1, final_result2, final_result3]
        final_result = self.weighted_majority_vote(pred_dicts, weights)
        return final_result

# %% [markdown]
# # **Load Data**

# %%
retriever = ImprovedDualEncoderRetrieval(
    retriever_model="sentence-transformers/multi-qa-mpnet-base-dot-v1",
    reranker_model="cross-encoder/ms-marco-MiniLM-L-12-v2",
    batch_size=16
)

# Set project directory path
PROJECT_DIR = '/content/drive/MyDrive/COMP90042_2025'
DATA_DIR = f'{PROJECT_DIR}/data/'

# Ensure directories exist
os.makedirs(DATA_DIR, exist_ok=True)

# Define file paths
EVIDENCE_PATH = f'{DATA_DIR}evidence.json'
TRAIN_CLAIMS_PATH = f'{DATA_DIR}train-claims.json'
DEV_CLAIMS_PATH = f'{DATA_DIR}dev-claims.json'
TEST_CLAIMS_PATH = f'{DATA_DIR}test-claims-unlabelled.json'

# Output file paths
EVIDENCE_EMBEDDINGS_PATH = f'{PROJECT_DIR}/evidence_embeddings_streamed.jsonl'
CLAIM_EMBEDDINGS_PATH = f'{PROJECT_DIR}/claim_embeddings.json'
RESULTS_PATH = f'{PROJECT_DIR}/retrieval_results.json'
METRICS_PATH = f'{PROJECT_DIR}/retrieval_metrics.json'
# Out:
# ✅ Loading retriever model [sentence-transformers/multi-qa-mpnet-base-dot-v1] in FP32
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Loading reranker model [cross-encoder/ms-marco-MiniLM-L-12-v2] in FP32
# config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.66k [00:00<?, ?B/s]

# %%
retriever.load_data(EVIDENCE_PATH, TRAIN_CLAIMS_PATH)
# Out:
# Loading evidence data from /content/drive/MyDrive/COMP90042_2025/data/evidence.json
# Loading claim data from /content/drive/MyDrive/COMP90042_2025/data/train-claims.json
# Loaded 1208827 evidence passages and 1228 claims
# True

# %% [markdown]
# # **combine 3 model Stage2&3**

# %% [markdown]
# Formating the json file

# %%
original_file = "/content/drive/MyDrive/COMP90042_2025/data/train-claims.json"  # The file used as standard Lable for evaluating. example: we use train data to predict so here is train-claims.
retrieved_file = "/content/drive/MyDrive/predictions_retriever20_reranker3.json" # The output file of stage 1.


with open(original_file, "r") as f:
    claim_data = json.load(f)

with open(retrieved_file, "r") as f:
    New_claim_data = json.load(f)


for cid in claim_data:    # Because the file output of our stage1 only has the evidences and claim_label, But we also need claim_text in the stage2.
    if cid in New_claim_data and 'evidences' in New_claim_data[cid]:
        claim_data[cid]['evidences'] = New_claim_data[cid]['evidences']


predictions_path = "/content/drive/MyDrive/predictions_retriever20_reranker3_1.json" # store the file for stage2.

with open(predictions_path, "w", encoding="utf-8") as f:
    json.dump(claim_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# Reading the formatted file and start

# %%
predictions_path = "/content/drive/MyDrive/predictions_retriever20_reranker3_1.json" # retrieval result from stage1. With fomat{claim-1:{claim_text: abc, claim_label: SUPPORT, evidences:[evidence1]}, claim-2...}
output_path = '/content/drive/MyDrive/outout1.json'
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
weights = [0.4,0.3,0.3]

final = retriever.combine_method(predictions_path = predictions_path, output_path = output_path, model_name = model_name, weights = weights)

file_name = '/content/drive/MyDrive/final_result' # output path

with open(file_name, "w", encoding="utf-8") as f:
    json.dump(final, f, ensure_ascii=False, indent=4)
# Out:
# first model
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-2657
# Claim: Currently, humans are emitting around 29 billion tonnes of carbon dioxide into the atmosphere per year.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-625
# Claim: I note particularly that sea-level rise is not affected by the warming; it continues at the same rate, 1.8 millimeters a year, according to a 1990 review by Andrew S. Trupin and John Wahr.
# Predicted: DISPUTED, Actual: REFUTES
#
# Claim ID: claim-1619
# Claim: Hansen predicted in 1988 the West Side Highway would be underwater in 20 years.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2921
# Claim: The tax-payer funded National Oceanic and Atmospheric Administration  (NOAA) has become mired in fresh global warming data scandal involving  numbers for the Great Lakes region that substantially ramp up averages."
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1146
# Claim: “It’s far too early to tell if what we are seeing in the Arctic, and now the Antarctic, is a sharp shift towards warmer poles with less ice.
# Predicted: DISPUTED, Actual: REFUTES
#
# Claim ID: claim-1773
# Claim: The global trend is calculated from hundreds of CO2 measuring stations and confirmed by satellites.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1204
# Claim: Back in the late 1980s, the UN claimed that if global warming were not checked by 2000, rising sea levels would wash entire counties away.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-849
# Claim: The most notorious was 252 million years ago; it began when carbon warmed the planet by five degrees, accelerated when that warming triggered the release of methane in the Arctic, and ended with 97 percent of all life on Earth dead.”
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-240
# Claim: In 1990 the United Nation’s Intergovernmental Panel on Climate Change (IPCC) predicted that temperatures would rise by 0.54F (0.3C) per decade.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-2531
# Claim: "In 1999 New Scientist reported a comment by the leading Indian glaciologist Syed Hasnain, who said in an email interview with this author that all the glaciers in the central and eastern Himalayas could disappear by 2035.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-2880
# Claim: For example, geothermal energy is available at all times, concentrated solar thermal energy has storage capability, and wind energy can be stored in compressed air.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2076
# Claim: Snowfall is increasing in the fall and winter in the Northern Hemisphere and North America with many records being set.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2508
# Claim: "The Pacific Decadal Oscillation (PDO) is a temperature pattern in the Pacific Ocean that spends roughly 20-30 years in the cool phase or the warm phase.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2049
# Claim: The Millennium Drought starting in 1997 and ending in 2010 was misinterpreted as a long term trend as a consequence of Climate Change.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1333
# Claim: “The oceans will never become acid because there is such a huge buffering capacity in the oceans.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1316
# Claim: In pushing too hard for the case that global warming is universally bad for everything, the administration’s report undermines the reasonable case for climate action.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1504
# Claim: Climate scientists say that aspects of the case of Hurricane Harvey suggest global warming is making a bad situation worse.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-243
# Claim: In its 5th assessment report in 2013, the IPCC estimated that human emissions are probably responsible for more than half of the observed increase in global average temperature from 1951 to 2010.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2302
# Claim: Since the mid 1970s, global temperatures have been warming at around 0.2 degrees Celsius per decade.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-502
# Claim: But abnormal temperature spikes in February and earlier this month have left it vulnerable to winds, which have pushed the ice further away from the coast than at any time since satellite records began in the 1970s.”
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-3093
# Claim: Sending oscillating microwaves from an antenna inside a vacuum through an electromagnetic field through a dielectric material, such as water, creates radio frequency heating at the molecular level
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# third model
# Claim ID: claim-1937
# Claim: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-126
# Claim: El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2510
# Claim: In 1946, PDO switched to a cool phase.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2021
# Claim: Weather Channel co-founder John Coleman provided evidence that convincingly refutes the concept of anthropogenic global warming.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2449
# Claim: "January 2008 capped a 12 month period of global temperature drops on all of the major well respected indicators.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-851
# Claim: The last time the planet was even four degrees warmer, Peter Brannen points out in The Ends of the World, his new history of the planet’s major extinction events, the oceans were hundreds of feet higher.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2773
# Claim: Tree-ring proxy reconstructions are reliable before 1960, tracking closely with the instrumental record and other independent proxies.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-949
# Claim: Under the most ambitious scenarios, they found a strong likelihood that Antarctica would remain fairly stable.”
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1019
# Claim: An additional kick was supplied by an El Niño weather pattern that peaked in 2016 and temporarily warmed much of the surface of the planet, causing the hottest year in a historical record dating to 1880.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2834
# Claim: When stomata-derived CO2 (red) is compared to ice core-derived CO2 (blue), the stomata generally show much more variability in the atmospheric CO2 level and often show levels much higher than the ice cores.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1441
# Claim: 195 countries signed the 2015 Paris Agreement, agreeing to limit global warming and adapt to climate change, partly by protecting nature.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1181
# Claim: However, there is a process of accretion, where coral broken up by the waves washes up on these low-lying islands as sand, counteracting the reduction in land mass.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2417
# Claim: Mars, Triton, Pluto and Jupiter all show global warming, pointing to the Sun as the dominating influence in determining climate throughout the solar system."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2152
# Claim: Venus doesn't have a runaway greenhouse effect
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-826
# Claim: The latest NOAA report is “a reminder that climate change has not, despite the insistence of climate contrarians ‘paused’ or even slowed down,” Mann said..
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1066
# Claim: […] in fact this pattern is already emerging, with the conditions that create extremely warm dry years and extremely wet years both becoming more frequent.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-3003
# Claim: Venus is not hot because of a runaway greenhouse.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-3059
# Claim: Models and direct observations find that CFCs only contribute a fraction of the warming supplied by other greenhouse gases.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-568
# Claim: The research also revealed how large areas of the polar ice caps could collapse and significant changes to ecosystems could see the Sahara Desert become green and the edges of tropical forests turn into fire-dominated savanna.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-60
# Claim: So that means that probably about half, maybe half of that nine-tenths of the degree [of total warming] might be caused by greenhouse gases
# Predicted: DISPUTED, Actual: DISPUTED
#
# Claim ID: claim-378
# Claim: for thousands of millions of years the Earth has been changing, with cycles­ and one-off events such as an asteroid impact, super-volcano or a supernova explosion.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2486
# Claim: The minute increase of anthropogenic CO2 in the atmosphere (0.008%) was not the cause of the warming—it was a continuation of natural cycles that occurred over the past 500 years."
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1782
# Claim: Thousands of coral atolls have "drowned" when unable to grow fast enough to survive at sea level.
# Predicted: DISPUTED, Actual: DISPUTED
#
# Claim ID: claim-1235
# Claim: “During ice ages, caused by wobbles in the Earth’s orbit, sea levels dropped more than 400 feet as ice piled up on land.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2065
# Claim: Global warming is causing snow to disappear.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1390
# Claim: “Lyme Disease is much more common in northern, cooler regions of the United States than in southern, warmer regions.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2789
# Claim: At that time, Hansen also produced a model of the future behavior of the globe’s temperature, which he had turned into a video movie that was heavily shopped in Congress.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1414
# Claim: The earth is 15 years from a “mini ice-age” that will cause bitterly cold winters during which rivers such as the Thames freeze over, scientists have predicted.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-377
# Claim: If we halve the carbon dioxide content of the atmosphere, all life dies.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-558
# Claim: Species that have a lot of plasticity tend to be generalists.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1447
# Claim: Flights departing airports in the United States and its territories emitted about one-quarter (24%) of global passenger transport-related CO2, two-thirds of which came from domestic flights.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1038
# Claim: (Multiplying .95 by itself 15 times yields 46.3 percent.)”
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2794
# Claim: But his results are evidence that the actual climate sensitivity is about 3°C for a doubling of atmospheric CO2.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-930
# Claim: “Right now, the shelf works like a giant bottle-stopper that slows down ice trying to flow from the land into the sea.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2763
# Claim: The long term trend from albedo is of cooling.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1920
# Claim: Melting of Arctic sea ice and polar icecaps is not occurring at unnatural rates and does not constitute evidence of a human impact on the climate.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2961
# Claim: Cooks ’97% consensus’ disproven by a new peer
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1395
# Claim: Severe storms, floods and agricultural losses may cost a great deal of money, but such extreme weather events—and their resulting costs—are dramatically declining as the Earth modestly warms.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1404
# Claim: receding polar ice caps have little if any negative impact on human health and welfare, and likely a positive benefit
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2257
# Claim: 'Our harmless emissions of trifling quantities of carbon dioxide cannot possibly acidify the oceans.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-646
# Claim: If Houlton’s finding about these vast, previously unknown nitrogen stores holds true, then it would have an enormous impact on global warming predictions.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1545
# Claim: Increasing CO2 in the atmosphere has little to no effect.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1317
# Claim: “…climate change will also reduce the number of cold days and cold spells.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1547
# Claim: Water vapor is the most powerful greenhouse gas.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2280
# Claim: While there are minor errors in An Inconvenient Truth, the main truths presented - evidence to show mankind is causing global warming and its various impacts is consistent with peer reviewed science.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-118
# Claim: more than 100 per cent of the warming over the past century is due to human actions
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1357
# Claim: “The notion that world-wide weather is becoming more extreme is just that: a notion, or a testable hypothesis.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-69
# Claim: Sea level rise is not going to happen.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2849
# Claim: "by the 2001 [IPCC] climate assessment...the Medieval Warm Period had been ingeniously wiped out.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-499
# Claim: The monetary cost of damages has increased dramatically in recent decades, but that is due to increasing population, wealth and the amount of vulnerable infrastructure.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-749
# Claim: “The worldwide temperature record has been changed.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-428
# Claim: Brooks added that Antarctic ice is growing.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1837
# Claim: A major part of the climate change bill sponsored by Sens. John Kerry and Joe Lieberman "was essentially written by BP."
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1875
# Claim: Doubling the concentration of atmospheric CO2 from its pre-industrial level, in the absence of other forcings and feedbacks, would likely cause a warming of ~0.3Â°C to 1.1Â°C
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1324
# Claim: cold deaths actually occur during moderate temperatures
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1980
# Claim: and three Nobel economic laureates support "direct investment in technology" rather than a carbon tax.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-409
# Claim: as time progresses and fossil fuel emissions increase, the number of record highs should increase and record lows should decrease.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2193
# Claim: In the last 35 years of global warming, the sun has shown a slight cooling trend.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-3084
# Claim: "the temperature increase in the second half of the 20th century could have taken place in steps driven by major ENSO events" (Jens Raunsø Jensen)
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1227
# Claim: These tidal floods are often just a foot or two deep, but they can stop traffic, swamp basements, damage cars, kill lawns and forests, and poison wells with salt.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1499
# Claim: Sea-level rise does not seem to depend on ocean temperature, and certainly not on CO2.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1790
# Claim: Study finds low probability of both very low and very high climate sensitivities, and its lower estimate (as compared to the IPCC) is based on a new temperature reconstruction of the Last Glacial Maximum that may or may not withstand the test of time.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2090
# Claim: Arctic icemelt is a natural cycle
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2199
# Claim: The consequences of climate change become increasingly bad after each additional degree of warming, with the consequences of 2°C being quite damaging and the consequences of 4°C being potentially catastrophic.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1498
# Claim: carbon dioxide has had a minuscule effect on global climate.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1792
# Claim: Greenland's ice loss is accelerating & will add metres of sea level rise in upcoming centuries.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2540
# Claim: In other words, there is as yet no incontrovertible  proof either of the greenhouse effect, or its connection with alleged  global warming.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2474
# Claim: Warming trends agree well with surface temperatures and model predictions except near the Poles.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2741
# Claim: 'Phil Jones said that for the past 15 years there has been no "statistically significant" warming.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-3102
# Claim: ...there [is] anecdotal and other evidence suggesting similar melts from 1938-43 and on other occasions.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1112
# Claim: “The jet stream forms a boundary between the cold north and the warmer south, but the lower temperature difference means the winds are now weaker.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2488
# Claim: However, it is unable to explain the long term warming trend over the past few decades.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1802
# Claim: The temporary drop in sea level in 2010 was due to intense land flooding caused by a strong La Nina.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-815
# Claim: Evidence is growing that the comparatively cold zone within the Northern Atlantic could be due to a slowdown of this global ocean water circulation.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2698
# Claim: The Review concluded that CRU's actions were normal and did not threaten the integrity of peer review.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1142
# Claim: Even as sea ice in the Arctic has seen a rapid and consistent decline over the past decade, its counterpart in the Southern Hemisphere has seen its extent increasing.”
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2707
# Claim: The full data for latitudes 64-90°N reveal the Arctic is warmer today than in 1940.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1260
# Claim: The contrast in precipitation between wet and dry regions and between wet and dry seasons will increase, although there may be regional exceptions.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1163
# Claim: “Global warming and climate change, even if it is 100% caused by humans, is so slow that it cannot be observed by anyone in their lifetime.
# Predicted: DISPUTED, Actual: REFUTES
#
# Claim ID: claim-740
# Claim: “To revisit the ocean’s paleotemperatures now, we need to carefully quantify this re-equilibration, which has been overlooked for too long.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1061
# Claim: warmer oceans have also begun to destabilize glaciers in Greenland and Antarctica
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2283
# Claim: In fact, the global melt rate has been accelerating since the mid-1970s.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1822
# Claim: Trudeau's carbon tax will raise gas prices by 11 cents/litre.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-332
# Claim: Shelters in poorer countries are not repainted as often, and darker stations absorb more of the sun’s energy.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-258
# Claim: But the period has caused a headache for climate scientists because clearly there was no upswell in carbon dioxide that could account for such swift warming.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-774
# Claim: The warming is extremely rapid on the geologic time scale, and no other factor can explain it as well as human emissions of greenhouse gases.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-207
# Claim: Each of the six major past ice ages began when the atmospheric carbon dioxide content was far higher than at present.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2966
# Claim: Over the three years from 1979 to 1982 when CO2 emissions were decreasing due to the rapid increase in the price of oil that drastically reduced consumption, there was no change in the rate of increase in atmospheric concentration of CO2 proving that humans were not the primary source for the increase in concentration.'
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-450
# Claim: If we double atmospheric carbon dioxide[…] we’d only raise global surface temperatures by about a degree Celsius.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-362
# Claim: North America suffers extreme weather events including wildfires, drought, and heatwaves.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2547
# Claim: The modelers confused cause and effect, thereby getting the feedback in the wrong direction."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-716
# Claim: Pollard and DeConto are the first to admit that their model is still crude, but its results have pushed the entire scientific community into emergency mode.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1708
# Claim: The 'decline' refers to a decline in northern tree-rings, not global temperature, and is openly discussed in papers and the IPCC reports.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1678
# Claim: No known natural forcing fits the fingerprints of observed warming except anthropogenic greenhouse gases.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1334
# Claim: We simply could never release enough CO2 into the atmosphere to cause the pH to go below 7 [the point in the pH scale at which a solution becomes acidic].”
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-61
# Claim: [NASA] has been adjusting temperatures from the past[...]
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1826
# Claim: Every year air pollution protections are delayed, another 34,000 people will die prematurely.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-157
# Claim: Contemporary Global Warming placed in geological context.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1481
# Claim: Based on the increase of solar activity during the twentieth century, it should account for between half to two-thirds of all climate change.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1796
# Claim: Natural cycles superimposed on a linear warming trend can be mistaken for step changes, but the underlying warming is caused by the external radiative forcing.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-807
# Claim: the total area burned in the western United States over the past 33 years was double the size it would have been without any human-caused warming.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1658
# Claim: Rising CO2 increases atmospheric water vapor, which makes global warming much worse.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-493
# Claim: Coastal lake sediments along the Gulf of Mexico shoreline from 1,000 to 2,000 years ago suggest more frequent and intense hurricanes than occur today.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2485
# Claim: A natural cycle requires a forcing, and no known forcing exists that fits the fingerprints of observed warming - except anthropogenic greenhouse gases.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-2222
# Claim: A large number of ancient mass extinction events have been strongly linked to global climate change.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2606
# Claim: ...Livestock are responsible for 18 per cent of the  greenhouse gases that cause global warming, more than cars, planes and  all other forms of transport put together.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-534
# Claim: Domino-effect of climate events could move Earth into a ‘hothouse’ state
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1313
# Claim: Coral bleaching has devastated 93% of the Great Barrier Reef
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1505
# Claim: according, again, to the official figures—during this past 10 years, if anything, mean global temperature, average world temperature, has slightly declined.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-282
# Claim: The panel was forced to retract a statement in its 2007 report saying all Himalayan glaciers could melt entirely by 2035.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-957
# Claim: ever since December temperatures in the Arctic have consistently been lower than minus 20 C
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-132
# Claim: Climate change is not making natural disasters worse
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1814
# Claim: The amount of heat energy coming out of the Earth is too small to even be worth considering.
# Predicted: DISPUTED, Actual: DISPUTED
#
# Claim ID: claim-363
# Claim: Monsoons in China fail, the great rivers of Asia virtually dry up, and rainfall in central America falls by half.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2687
# Claim: It seems scientists have noticed recently that quite a few planets in our solar system seem to be heating up a bit, including Pluto."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1294
# Claim: “Because CO₂ acts as a fertilizer, as much as half of all vegetated land is persistently greener today.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-649
# Claim: “Houlton has been exploring this possibility for years.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2868
# Claim: "I mean, it - I mean - and I tell somebody, I said, just because you have a group of scientists that have stood up and said here is the fact, Galileo got outvoted for a spell" (Texas Governor Rick Perry)
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1562
# Claim: Methane is the only cause of climate change.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1620
# Claim: Great Barrier Reef is in good shape.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1327
# Claim: Migration patterns show people heading for warm states like Texas and Florida, not snowy Minnesota and Michigan.”
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-3103
# Claim: "Disasters Cost More Than Ever — But Not Because of Climate Change" (Roger Pielke Jr.)
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-195
# Claim: Carbon dioxide is a non-condensable atmospheric gas like nitrogen and oxygen
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-642
# Claim: Some experts think we’re on track to hit 550 ppm by the end of the century, which would cause average global temperatures to rise by 6 degrees Celsius
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2494
# Claim: There is ample evidence that Earth's average temperature has increased in the past 100 years and the decline of mid- and high-latitude glaciers is a major piece of evidence.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1116
# Claim: Severe ‘snowmageddon’ winters are now strongly linked to soaring polar temperatures, say researchers, with deadly summer heatwaves and torrential floods also probably linked.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-3048
# Claim: There is no question whatsoever that the CO2 increase is human-caused.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1115
# Claim: This “blocking” effect means extreme events can unfold.”
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1614
# Claim: Arctic sea ice extent was lower in the past.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1580
# Claim: Plant stomata show higher and more variable CO2 levels.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-593
# Claim: It shows that ECS is probably between two and 4.5 degrees, possibly as low as 1.5 but not lower, and possibly as high as nine degrees.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2560
# Claim: In the 11,400 years since the end of the last Ice Age, sea  level has risen at an average of 4 feet/century, though it is now rising  much more slowly because very nearly all of the land-based ice that is  at low enough latitudes and altitudes to melt has long since gone."
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-11
# Claim: They tell us that we are the primary forces controlling earth temperatures by the burning of fossil fuels and releasing their carbon dioxide.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1339
# Claim: “Dr Browman, a marine scientist for 35 years, said he was not saying that ocean acidification posed no threat, but that he believed that “a higher level of academic scepticism” should be applied to the topic.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1878
# Claim: During the 2013 election campaign the Coalition said its first legislative priority in government would be to scrap the carbon tax.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2120
# Claim: Phil Jones says no global warming since 1995
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1098
# Claim: Marine life has nothing whatsoever to fear from ocean acidification.”
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2078
# Claim: Droughts and floods have not changed since weve been using fossil fuels
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-797
# Claim: Climate Models Have Overestimated Global Warming
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1667
# Claim: Mars and Jupiter are not warming, and anyway the sun has recently been cooling slightly.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2553
# Claim: The climate debate is, in reality, about a 1.6 watts per square metre or 0.5 per cent discrepancy in the poorly known planetary energy balance."
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2029
# Claim: Bill Gates claims pandemic's 'misery' will 'happen regularly' if climate change is not stopped
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1049
# Claim: So far this month, there have been nearly 5,000 daily record highs set or tied, compared to just 42 daily record lows.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1744
# Claim: The claim sea level isn’t rising is based on blatantly doctored graphs contradicted by observations.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2782
# Claim: "NASA satellite data from the years 2000 through 2011 show the Earth's atmosphere is allowing far more heat to be released into space than alarmist computer models have predicted, reports a new study in the peer-reviewed science journal Remote Sensing.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2432
# Claim: The sun was warming up then, but the sun hasn’t been warming since 1970.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2805
# Claim: Arctic sea ice loss is three times greater than Antarctic sea ice gain, and the amount of solar energy absorbed by the Earth is increasing as a result.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-821
# Claim: Societies do fall apart from war, disease or chaos.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1931
# Claim: New Jersey is "losing 50 football fields of open space to development every day and the more we develop upstream the more flooding we have downstream."
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1084
# Claim: [Jonathan Overpeck:] ‘No doubt about it anymore — humans, mainly by burning fossil fuels, are cooking the planet,’ Overpeck said.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2788
# Claim: 'On June 23, 1988, NASA scientist James Hansen testified before the House of Representatives that there was a strong "cause and effect relationship" between observed temperatures and human emissions into the atmosphere.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1465
# Claim: Since the beginning of the Industrial Revolution, the acidity of surface ocean waters has increased by about 30 percent.13,14
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1938
# Claim: Obama administration's Clean Power Plan would have little or no effect on carbon dioxide emissions.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2123
# Claim: Tree-rings diverge from temperature after 1960
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1406
# Claim: Yet, according to NASA, only one temperature sensing station is necessary for the two cities and the vast area between them to be adequately represented in their network.”
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2444
# Claim: There are a number of forcings which affect climate (eg - stratospheric aerosols, solar variations).
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-320
# Claim: Globally averaged thermometers show two periods of warming since 1900: a half-degree from natural causes in the first half of the 20th century, before there was an increase in industrial carbon dioxide that was enough to produce it, and another half-degree in the last quarter of the century.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1880
# Claim: Electricity rates are 40 percent higher in states that have required utility companies to use a certain amount of renewable energy such as solar power.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-263
# Claim: it later emerged that its creator Dr Michael Mann had spliced too [sic] datasets together – tree-rings showing temperatures going back hundreds of years, then recent thermometer readings for the more recent decades.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-663
# Claim: “For example, Canadian polar bear biologist Ian Stirling learned in the 1970s that spring sea ice in the southern Beaufort Sea periodically gets so thick that seals depart, depriving local polar bears of their prey and causing their numbers to plummet.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1995
# Claim: There are about 120,000 solar energy jobs in the United States, but only 1,700 of them are in Georgia.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2780
# Claim: The United States has been restricting soot emissions  in Draconian fashion since the Clean Air Act of 1963.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2369
# Claim: The public understand it, in that if  you get a fall evening or spring evening and the sky is clear the heat  will escape and the temperature will drop and you get frost.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2627
# Claim: Neptune's orbit is 164 years so observations (1950 to present day) span less than a third of a Neptunian year.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1077
# Claim: Antarctic ice fluctuates wildly year to year, and the link to man-made global warming there is not clear, NASA ice expert Walt Meier said.
# Predicted: DISPUTED, Actual: DISPUTED
#
# Claim ID: claim-828
# Claim: Famine, economic collapse, a sun that cooks us: What climate change could wreak — sooner than you think.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2461
# Claim: Early 20th century warming was in large part due to rising solar activity and relatively quiet volcanic activity.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2945
# Claim: But that conclusion holds true only if there are no other sources of c12 increases which are not human caused.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2633
# Claim: Jupiter's climate change is due to shifts in internal turbulence fueled from an internal heat source - the planet radiates twice as much energy as it receives from the sun.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-353
# Claim: The bottom line is there’s no solid connection between climate change and the major indicators of extreme weather
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1829
# Claim: "the cascading effects" of climate change contributed to the rise of ISIS.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1568
# Claim: Southern sea ice is increasing.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-791
# Claim: ‘Clean coal’ is an approach in which the emissions from coal-burning power plants would be captured and pumped underground.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1634
# Claim: Satellites measure Antarctica losing land ice at an accelerating rate.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2202
# Claim: More specifically, around 95% of active climate researchers actively publishing climate papers endorse the consensus position.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-337
# Claim: temperatures were 6-10C above normal over most of France, Germany and northern Spain during the final days of the month, according to C3S.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1674
# Claim: Early 20th century warming is due to several causes, including rising CO2.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2255
# Claim: And  since the last ice age ended almost exactly 11,500 years ago…" (Ice Age Now)
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1988
# Claim: The Obama administration's "own Environmental Protection Agency" has said its Clean Power Plan "will have a marginal impact on climate change."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1376
# Claim: Also, it is increasingly clear that the planet was significantly warmer than today several times during the past 10,000 years.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2649
# Claim: "Mike's Nature trick" has nothing to do with "hide the decline", instead refering to a technique by Michael Mann to plot instrumental temperature along with past reconstructions.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1923
# Claim: More than 260,000 Americans are employed by the domestic solar industry â three times as many workers as employed by the entire coal mining industry.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-133
# Claim: The amount of land we use for meat — humankind’s biggest use of land — has declined by an area nearly as large as Alaska
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2927
# Claim: CO2 changes are closely related to temperature.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-688
# Claim: “The arc of global warming will be variously steep and less steep,’ said Richard Seager, a climate scientist at the Lamont-Doherty Earth Observatory of Columbia University.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1712
# Claim: The sun has not warmed since 1970 and so cannot be driving global warming.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1817
# Claim: Environment Minister Greg Hunt the Coalition's emissions reduction fund, at $13.95 per tonne of carbon, is around 1 per cent of the cost of reducing carbon under the former Labor government's carbon pricing scheme, which he cost $1,300 a tonne.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2067
# Claim: Arctic, Antarctic and Greenland ice loss is accelerating due to global warming.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-3052
# Claim: "...there has been no increase in the global average surface temperature for the past 16 years" (Judith Curry and David Rose)
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1157
# Claim: “In 2013 the level of U.S. farm output was about 2.7 times its 1948 level, and productivity was growing at an average annual rate of 1.52%.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1246
# Claim: Most people expect this year will see a record low in the Arctic’s summer sea-ice cover.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-564
# Claim: This could mean the landmark Paris Climate Agreement – which seeks to limit global warming to 2 degrees Celsius (3.6 degrees Fahrenheit) above pre-industrial levels – may not be enough to ward off catastrophe.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1866
# Claim: Climate scientists have predicted global temperatures would increase more than one degree Celsius by 2020," but observed temperatures have been only half as high.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1454
# Claim: The oceans have absorbed much of this increased heat, with the top 700 meters (about 2,300 feet) of ocean showing warming of more than 0.4 degrees Fahrenheit since 1969.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-129
# Claim: Sea level rise could reach six or seven feet by the year 2100.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1616
# Claim: UAH atmospheric temperatures prove climate models and/or surface temperature data sets are wrong.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1948
# Claim: Recent record-low water levels in Lake Michigan are evidence that global warming is leading to "the evaporation of our Great Lakes."
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-614
# Claim: The Rio Grande is a classic “feast or famine” river, with a dry year or two typically followed by a couple of wet years that allow for recovery.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-868
# Claim: In Alaska, already, researchers have discovered remnants of the 1918 flu that infected as many as 500 million and killed as many as 100 million”
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1665
# Claim: The effects of enhanced CO2 on terrestrial plants are variable and complex and dependent on numerous factors.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-2453
# Claim: "The killer proof that CO2 does not drive climate is to be found during the Ordovician- Silurian and the Jurassic-Cretaceous periods when CO2 levels were greater than 4000 ppmv (parts per million by volume) and about 2000 ppmv respectively.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2267
# Claim: Focusing on a few suggestive emails, taken out of context, merely serves to distract from the wealth of empirical evidence for man-made global warming.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-390
# Claim: there were no ice sheets covering either Greenland or West Antarctica, and much of the East Antarctic ice sheet was gone.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-216
# Claim: [The 1990 IPCC report said] that the Antarctic ice sheets were stable
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-905
# Claim: “Some experts, such as UN climate scientist Dr. Indur Goklany, have defended rising CO2 levels as a good thing for humanity.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2826
# Claim: A drop of volcanic activity in the early 20th century may have had a warming effect.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2775
# Claim: For instance, in the original hockey stick (ending 1980) the last 30-40 years of data points slightly downwards.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2141
# Claim: Satellite error inflated Great Lakes temperatures
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2482
# Claim: The warm and cool regions roughly balance each other out with little impact on global temperature.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-582
# Claim: On the other side of the Atlantic ocean, climates are typically milder as a result of the cooling from the Gulf Stream.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-708
# Claim: Before human burning of fossil fuels triggered global warming, the continent’s ice was in relative balance
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-412
# Claim: From 1970 until 1998 there was a warming period that raised temperatures by about 0.7 F that helped spawn the global warming alarmist movement.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1855
# Claim: Barack Obama will help the Gulf Coast restore the wetlands, marshes and barrier islands that are critical to tamping down the force of hurricanes.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1999
# Claim: there is no relationship between temperature and carbon dioxide emissions by Â­humans[...]
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-3130
# Claim: "There are other possible causes for climate change which could be associated with solar activity or related to variations in the temperature of the liquid core of the Earth, which is about 5,400 degrees Celsius.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-85
# Claim: Sea-level rise does not seem to depend on ocean temperature, and certainly not on CO2
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2030
# Claim: Opponents of climate action are getting twice as much airtime as proponents of climate action.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-470
# Claim: According to NASA, the globally averaged temperature of the land and ocean was 0.9˚C (1.62˚F) above the 20th century average.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1932
# Claim: Newspaper Article from 1922 Discusses Arctic Ocean Climate Change
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2506
# Claim: The IPCC confirms that computer modeling predicts the existence of a tropical, mid-troposphere “hot spot” about 10km above the Earth’s surface.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1825
# Claim: Climate change is a hoax invented by the Chinese.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1007
# Claim: ‘With levels of carbon dioxide in the atmosphere consistently breaking new records, the influence of human activities on the climate system has become more and more evident,’ said Taalas.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1205
# Claim: “In 2009, then-British Prime Minister Gordon Brown predicted that the world had only 50 days to save the planet from global warming.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1783
# ...
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1022
# Claim: If water temperatures stay moderate, the damaged sections of the Great Barrier Reef may be covered with corals again in as few as 10 or 15 years
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-44
# Claim: Human-produced carbon might be one of the factors [of climate change], but there’s simply no evidence that it is a significant one.
# Predicted: DISPUTED, Actual: REFUTES
#
# Claim ID: claim-2244
# Claim: So CO2 causes warming AND rising temperature causes CO2 rise.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2693
# Claim: While there are many drivers of climate, CO2 is the most dominant radiative forcing and is increasing faster than any other forcing.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-549
# Claim: The extent of climate change’s influence on the jet stream is an intense subject of research.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-3082
# Claim: "However, a single scientist, Dr. Ben Santer of Lawrence Livermore National Laboratory, rewrote the draft at the IPCC’s request, deleting all five statements, replacing them with a single statement to the effect that a human influence on global climate was now discernible, and making some 200 consequential amendments.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-77
# Claim: [S]unspot activity on the surface of our star has dropped to a new low.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-93
# Claim: unadjusted data suggests that temperatures in Australia have only increased by 0.3 degrees over the past century, not the 1 degree usually claimed
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-909
# Claim: Meeting the 2025 emissions reduction target alone could subtract $250 billion from our GDP and eliminate 2.7 million jobs.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-449
# Claim: So it’s clear now we’re not seeing dangerous global warming, and the climate models are wrong.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1178
# Claim: “The most famous of these studies, published in 2010 by Paul Kench and Arthur Webb of the South Pacific Applied Geoscience Commission in Fiji, showed that of 27 Pacific islands, 14% lost area.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2173
# Claim: We didn't have global warming during the Industrial Revolution
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-817
# Claim: Scientists have long known about the anomalous ‘warming hole‘ in the North Atlantic Ocean, an area immune to warming of Earth’s oceans.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1721
# Claim: Global sea level data shows that sea level rise has been increasing since 1880 while future sea level rise predictions are based on physics, not statistics.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-840
# Claim: At four degrees, the deadly European heat wave of 2003, which killed as many as 2,000 people a day, will be a normal summer.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2111
# Claim: 'Global warming' and 'climate change' mean different things and have both been used for decades.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1586
# Claim: Ice Sheet losses are overestimated.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-995
# Claim: “The Northern Hemisphere jet stream […] flow is stronger when that temperature difference is large.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1014
# Claim: Final data for 2016 sea level rise have yet to be published.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-200
# Claim: if we halved today’s atmospheric carbon dioxide content, all life would die.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-442
# Claim: There is no empirical evidence that increasing greenhouse gases are the primary cause of Global Warming
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-399
# Claim: Climate Change ‘Heat Records’ Are a Huge Data Manipulation
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-1602
# Claim: Antarctica is too cold to lose ice.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-3124
# Claim: the Great Barrier Reef is in fine fettle
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1874
# Claim: Donald Trump signed an executive order naming climate change as a threat "both to the economy and national security."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-590
# Claim: Their ECS estimate is 1.5 degrees, with a probability range between 1.05 and 2.45 degrees.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1421
# Claim: The melting in the polar ice caps and in high altitude plains can lead to the dangerous release of methane gas
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2661
# Claim: Current CO2 levels are the highest in 15 million years.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1476
# Claim: The consensus among scientists and policy-makers is that we’ll pass this point of no return if the global mean temperature rises by more than two degrees Celsius.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-71
# Claim: Cold weather to grip world as solar minimum to deepen, NASA says
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-551
# Claim: Gone are the days when scientists drew a bright line dividing weather and climate.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2261
# Claim: Last December, the respected  journal “Oceanography” published projections (see graphic below) for this rising acidity, measured by falling pH
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2608
# Claim: And their wind and manure emit more than one third of  emissions of another, methane, which warms the world 20 times faster  than carbon dioxide.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1149
# Claim: Temperatures in the Arctic have soared recently, and scientists are struggling to explain exactly why.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1093
# Claim: Ocean acidification is the terrifying threat whereby all that man-made CO2 we’ve been pumping into the atmosphere may react with the sea to form a sort of giant acid bath.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-2726
# Claim: Humans are emitting 26 gigatonnes of CO2 into the atmosphere.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1492
# Claim: Sea level rise due to climate change is not going to happen.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1270
# Claim: The world’s alpine glaciers recorded a net annual loss of ice for the 36th consecutive year and the Greenland ice sheet … experienced melting over more than 50% of its surface.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-211
# Claim: For decades, most scientists saw climate change as a distant prospect.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2205
# Claim: "In fact global warming has stopped and a cooling is beginning.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-484
# Claim: “We almost take forests as a given but we lose forest every year, which means we are diminishing them as a carbon sink.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1485
# Claim: The human contribution to global warming was about 0.01°C.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1724
# Claim: Lindzen and Choi’s paper is viewed as unacceptably flawed by other climate scientists.
# Predicted: DISPUTED, Actual: SUPPORTS
#
# Claim ID: claim-498
# Claim: The 30 most costly hurricanes in U.S. history (according to federal data from January) show no increase in intensity over time.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1474
# Claim: Etna has already put more than 10,000 times the CO2 into the atmosphere than mankind has in our entire time on the Earth.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-250
# Claim: CO2 is not powerful in that sense, the only thing it does in the system is make the planet greener.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2378
# Claim: The costs of inaction far outweigh the costs of mitigation.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2390
# Claim: There may have been regions of Greenland that were 'greener' than today
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2136
# Claim: Renewables can't provide baseload power
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1155
# Claim: But observations, such as those on our CO2 Coalition website, show that increased CO2 levels over the next century will cause modest and beneficial warming—perhaps as much as one degree Celsius (1.8 degrees Fahrenheit)
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-189
# Claim: The geological history of the planet shows major planetary climate changes have never been driven by a trace gas
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1569
# Claim: Sea level rise is decelerating.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2704
# Claim: Australia accounts for 1.5 per cent of global carbon emissions.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-2366
# Claim: Increased CO2 makes more water vapor, a greenhouse gas which amplifies warming
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-919
# Claim: an airplane is contributing to the emissions that put the frozen continent at risk.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2570
# Claim: The IPCC statement on Amazon rain forests is correct.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2584
# Claim: Once the atmosphere reaches a saturation point, additional input of CO2 will not really have any major impact.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2738
# Claim: When you read Phil Jones' actual words, you see he's saying there is a warming trend
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-169
# Claim: They can now model how likely a specific event would be to occur under historical conditions, compared to the record temperatures we’re experiencing.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-939
# Claim: “Recent computer forecasts suggest that if greenhouse gas emissions continue at a high level, parts of Antarctica could break up rapidly, causing the ocean to rise six feet or more by the end of this century.
# Predicted: SUPPORTS, Actual: DISPUTED
#
# Claim ID: claim-1798
# Claim: A few degrees of global warming has a huge impact on ice sheets, sea levels and other aspects of climate.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-165
# Claim: When the Emergency Leaders for Climate Action approached the Federal Government in April they were drawing on decades of data showing that fire conditions are getting worse.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-775
# Claim: Instead of negotiating over climate change policies and trying to make them more market-oriented, some political conservatives have taken the approach of blocking them by trying to undermine the science.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2657
# Claim: Currently, humans are emitting around 29 billion tonnes of carbon dioxide into the atmosphere per year.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-625
# Claim: I note particularly that sea-level rise is not affected by the warming; it continues at the same rate, 1.8 millimeters a year, according to a 1990 review by Andrew S. Trupin and John Wahr.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1619
# Claim: Hansen predicted in 1988 the West Side Highway would be underwater in 20 years.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-2921
# Claim: The tax-payer funded National Oceanic and Atmospheric Administration  (NOAA) has become mired in fresh global warming data scandal involving  numbers for the Great Lakes region that substantially ramp up averages."
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1146
# Claim: “It’s far too early to tell if what we are seeing in the Arctic, and now the Antarctic, is a sharp shift towards warmer poles with less ice.
# Predicted: SUPPORTS, Actual: REFUTES
#
# Claim ID: claim-1773
# Claim: The global trend is calculated from hundreds of CO2 measuring stations and confirmed by satellites.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1204
# Claim: Back in the late 1980s, the UN claimed that if global warming were not checked by 2000, rising sea levels would wash entire counties away.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-849
# Claim: The most notorious was 252 million years ago; it began when carbon warmed the planet by five degrees, accelerated when that warming triggered the release of methane in the Arctic, and ended with 97 percent of all life on Earth dead.”
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-240
# Claim: In 1990 the United Nation’s Intergovernmental Panel on Climate Change (IPCC) predicted that temperatures would rise by 0.54F (0.3C) per decade.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2531
# Claim: "In 1999 New Scientist reported a comment by the leading Indian glaciologist Syed Hasnain, who said in an email interview with this author that all the glaciers in the central and eastern Himalayas could disappear by 2035.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2880
# Claim: For example, geothermal energy is available at all times, concentrated solar thermal energy has storage capability, and wind energy can be stored in compressed air.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2076
# Claim: Snowfall is increasing in the fall and winter in the Northern Hemisphere and North America with many records being set.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2508
# Claim: "The Pacific Decadal Oscillation (PDO) is a temperature pattern in the Pacific Ocean that spends roughly 20-30 years in the cool phase or the warm phase.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2049
# Claim: The Millennium Drought starting in 1997 and ending in 2010 was misinterpreted as a long term trend as a consequence of Climate Change.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-1333
# Claim: “The oceans will never become acid because there is such a huge buffering capacity in the oceans.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1316
# Claim: In pushing too hard for the case that global warming is universally bad for everything, the administration’s report undermines the reasonable case for climate action.
# Predicted: DISPUTED, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-1504
# Claim: Climate scientists say that aspects of the case of Hurricane Harvey suggest global warming is making a bad situation worse.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-243
# Claim: In its 5th assessment report in 2013, the IPCC estimated that human emissions are probably responsible for more than half of the observed increase in global average temperature from 1951 to 2010.
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# Claim ID: claim-2302
# Claim: Since the mid 1970s, global temperatures have been warming at around 0.2 degrees Celsius per decade.
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-502
# Claim: But abnormal temperature spikes in February and earlier this month have left it vulnerable to winds, which have pushed the ice further away from the coast than at any time since satellite records began in the 1970s.”
# Predicted: SUPPORTS, Actual: NOT_ENOUGH_INFO
#
# Claim ID: claim-3093
# Claim: Sending oscillating microwaves from an antenna inside a vacuum through an electromagnetic field through a dielectric material, such as water, creates radio frequency heating at the molecular level
# Predicted: SUPPORTS, Actual: SUPPORTS
#
# finish, start combine

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

def evaluate_with_ids(predictions_dict, actuals_dict):
    common_ids = set(predictions_dict.keys()) & set(actuals_dict.keys())

    y_pred = [predictions_dict[cid]["claim_label"] for cid in common_ids]
    y_true = [actuals_dict[cid]["claim_label"] for cid in common_ids]

    print("\n=== Evaluation Metrics ===")
    print(f"Accuracy: {accuracy_score(y_true, y_pred):.2%}")
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, digits=4))

# %%
actuals_dict={}
with open(original_file, 'r') as f:
      claim_data = json.load(f)
for claim_id, info in claim_data.items():
    evidences = info["evidences"]
    claim_label = info["claim_label"]
    actuals_dict[claim_id] = {
                    "claim_label": claim_label,
                    "evidences": evidences
                    }

# %%
evaluate_with_ids(final, actuals_dict)
# Out:
# === Evaluation Metrics ===
# Accuracy: 50.00%
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#        DISPUTED     0.2000    0.3306    0.2492       124
# NOT_ENOUGH_INFO     0.9073    0.3549    0.5102       386
#         REFUTES     0.8298    0.1960    0.3171       199
#        SUPPORTS     0.4812    0.7649    0.5908       519
#
#        accuracy                         0.5000      1228
#       macro avg     0.6046    0.4116    0.4168      1228
#    weighted avg     0.6432    0.5000    0.4866      1228

# %%
final
# Out:
# {'claim-1937': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-175662', 'evidence-12171', 'evidence-499734']},
#  'claim-126': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-494148', 'evidence-1066389', 'evidence-420577']},
#  'claim-2510': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-984887', 'evidence-84969', 'evidence-667390']},
#  'claim-2021': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-796796', 'evidence-230669', 'evidence-1146282']},
#  'claim-2449': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-110980', 'evidence-564624', 'evidence-430060']},
#  'claim-851': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-39815', 'evidence-65415', 'evidence-683138']},
#  'claim-2773': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-974673', 'evidence-903800', 'evidence-160755']},
#  'claim-949': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-964861', 'evidence-600447', 'evidence-1132388']},
#  'claim-1019': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-711111', 'evidence-420577', 'evidence-1088556']},
#  'claim-2834': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-439640', 'evidence-113446', 'evidence-217862']},
#  'claim-1441': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-217743', 'evidence-748431', 'evidence-853312']},
#  'claim-1181': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-337702', 'evidence-1015241', 'evidence-647382']},
#  'claim-2417': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-896175', 'evidence-333167', 'evidence-407097']},
#  'claim-2152': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-515817', 'evidence-791159', 'evidence-1018575']},
#  'claim-826': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-497197', 'evidence-235043', 'evidence-347965']},
#  'claim-1066': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-598028', 'evidence-457045', 'evidence-287752']},
#  'claim-3003': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-515817', 'evidence-791159', 'evidence-1018575']},
#  'claim-3059': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-556694', 'evidence-91026', 'evidence-844325']},
#  'claim-568': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-335967', 'evidence-169769', 'evidence-643935']},
#  'claim-60': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-741089', 'evidence-47605', 'evidence-1165029']},
#  'claim-378': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1014818', 'evidence-1017229', 'evidence-213014']},
#  'claim-2486': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-823476', 'evidence-878897', 'evidence-1050099']},
#  'claim-1782': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-308548', 'evidence-647382', 'evidence-592123']},
#  'claim-1235': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1109588', 'evidence-352802', 'evidence-843672']},
#  'claim-2065': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-4420', 'evidence-493171', 'evidence-1128954']},
#  'claim-1390': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-307215', 'evidence-1094006', 'evidence-501601']},
#  'claim-2789': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-297360', 'evidence-485819', 'evidence-594733']},
#  'claim-1414': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1135224', 'evidence-418973', 'evidence-939401']},
#  'claim-377': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-710477', 'evidence-707516', 'evidence-121187']},
#  'claim-558': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-738531', 'evidence-552428', 'evidence-742549']},
#  'claim-1447': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-331238', 'evidence-98833', 'evidence-821225']},
#  'claim-1038': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-997014', 'evidence-1122132', 'evidence-855668']},
#  'claim-2794': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1049371', 'evidence-158204', 'evidence-470418']},
#  'claim-930': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1199599', 'evidence-1150464', 'evidence-442866']},
#  'claim-2763': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-898871', 'evidence-311416', 'evidence-127271']},
#  'claim-1920': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-733280', 'evidence-1128954', 'evidence-851031']},
#  'claim-2961': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-364120', 'evidence-1083183', 'evidence-608883']},
#  'claim-1395': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-391922', 'evidence-1128833', 'evidence-981529']},
#  'claim-1404': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-634003', 'evidence-869636', 'evidence-1160433']},
#  'claim-2257': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1054050', 'evidence-973268', 'evidence-393408']},
#  'claim-646': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-17481', 'evidence-387380', 'evidence-323649']},
#  'claim-1545': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1049076', 'evidence-1007748', 'evidence-232533']},
#  'claim-1317': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1025337', 'evidence-53757', 'evidence-992706']},
#  'claim-1547': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-706949', 'evidence-986681', 'evidence-80853']},
#  'claim-2280': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-832371', 'evidence-424945', 'evidence-156038']},
#  'claim-118': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-525405', 'evidence-871977', 'evidence-1975']},
#  'claim-1357': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-458959', 'evidence-211687', 'evidence-140052']},
#  'claim-69': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-53555', 'evidence-149013', 'evidence-125488']},
#  'claim-2849': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-298630', 'evidence-33543', 'evidence-974202']},
#  'claim-499': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-975225', 'evidence-1069290', 'evidence-156434']},
#  'claim-749': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-868894', 'evidence-490170', 'evidence-880073']},
#  'claim-428': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1068851', 'evidence-427121', 'evidence-728645']},
#  'claim-1837': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-606697', 'evidence-477022', 'evidence-910990']},
#  'claim-1875': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-632574', 'evidence-100461', 'evidence-951142']},
#  'claim-1324': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-844578', 'evidence-894129', 'evidence-348427']},
#  'claim-1980': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-346472', 'evidence-301054', 'evidence-32316']},
#  'claim-409': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-886636', 'evidence-1107261', 'evidence-1016625']},
#  'claim-2193': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-996913', 'evidence-333748', 'evidence-979414']},
#  'claim-3084': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-722713', 'evidence-384754', 'evidence-542292']},
#  'claim-1227': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-163637', 'evidence-368882', 'evidence-155048']},
#  'claim-1499': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-12011', 'evidence-605613', 'evidence-399273']},
#  'claim-1790': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-902107', 'evidence-557203', 'evidence-867241']},
#  'claim-2090': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-824669', 'evidence-867263', 'evidence-1172097']},
#  'claim-2199': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-721769', 'evidence-442573', 'evidence-924647']},
#  'claim-1498': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-950498', 'evidence-1007748', 'evidence-121664']},
#  'claim-1792': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1056186', 'evidence-264761', 'evidence-391045']},
#  'claim-2540': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-714675', 'evidence-742544', 'evidence-806019']},
#  'claim-2474': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-198457', 'evidence-721744', 'evidence-798926']},
#  'claim-2741': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1174955', 'evidence-1142444', 'evidence-389165']},
#  'claim-3102': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-48210', 'evidence-499252', 'evidence-913091']},
#  'claim-1112': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-459315', 'evidence-921243', 'evidence-427299']},
#  'claim-2488': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-431058', 'evidence-223282', 'evidence-13780']},
#  'claim-1802': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-163637', 'evidence-792643', 'evidence-4318']},
#  'claim-815': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-819529', 'evidence-1046646', 'evidence-337561']},
#  'claim-2698': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-519557', 'evidence-1167663', 'evidence-175896']},
#  'claim-1142': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-253690', 'evidence-858052', 'evidence-1172097']},
#  'claim-2707': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-845573', 'evidence-569887', 'evidence-967158']},
#  'claim-1260': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-773322', 'evidence-485667', 'evidence-117400']},
#  'claim-1163': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-881808', 'evidence-1024707', 'evidence-458959']},
#  'claim-740': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1007847', 'evidence-386068', 'evidence-1121998']},
#  'claim-1061': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-624644', 'evidence-797505', 'evidence-975870']},
#  'claim-2283': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1048619', 'evidence-911449', 'evidence-1056909']},
#  'claim-1822': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-751210', 'evidence-150674', 'evidence-891812']},
#  'claim-332': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1138724', 'evidence-1001920', 'evidence-1050787']},
#  'claim-258': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-897934', 'evidence-110980', 'evidence-315466']},
#  'claim-774': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1150379', 'evidence-110835', 'evidence-338219']},
#  'claim-207': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-683138', 'evidence-504449', 'evidence-503975']},
#  'claim-2966': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-998171', 'evidence-823865', 'evidence-446665']},
#  'claim-450': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-725977', 'evidence-100461', 'evidence-1165029']},
#  'claim-362': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-468651', 'evidence-13434', 'evidence-3785']},
#  'claim-2547': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-254876', 'evidence-29808', 'evidence-461362']},
#  'claim-716': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-528998', 'evidence-768331', 'evidence-230028']},
#  'claim-1708': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-736392', 'evidence-224185', 'evidence-464939']},
#  'claim-1678': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-878897', 'evidence-785914', 'evidence-1150379']},
#  'claim-1334': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-699934', 'evidence-296879', 'evidence-1184350']},
#  'claim-61': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1130952', 'evidence-9408', 'evidence-1054412']},
#  'claim-1826': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-7024', 'evidence-199318', 'evidence-472444']},
#  'claim-157': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-210566', 'evidence-1019658', 'evidence-1108323']},
#  'claim-1481': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-979414', 'evidence-127029', 'evidence-345545']},
#  'claim-1796': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-479999', 'evidence-1017229', 'evidence-1019658']},
#  'claim-807': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-67420', 'evidence-1150770', 'evidence-1180647']},
#  'claim-1658': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-855683', 'evidence-1007748', 'evidence-337493']},
#  'claim-493': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-885836', 'evidence-908316', 'evidence-479543']},
#  'claim-2485': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1017229', 'evidence-198943', 'evidence-202502']},
#  'claim-2222': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-403691', 'evidence-913068', 'evidence-1157800']},
#  'claim-2606': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-669881', 'evidence-675698', 'evidence-968712']},
#  'claim-534': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1084600', 'evidence-397392', 'evidence-37705']},
#  'claim-1313': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-670186', 'evidence-513559', 'evidence-510781']},
#  'claim-1505': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-637842', 'evidence-1042452', 'evidence-1183264']},
#  'claim-282': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-138717', 'evidence-907084', 'evidence-281372']},
#  'claim-957': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-269824', 'evidence-435345', 'evidence-285343']},
#  'claim-132': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-325870', 'evidence-415651', 'evidence-1055682']},
#  'claim-1814': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1142773', 'evidence-418973', 'evidence-154201']},
#  'claim-363': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-988395', 'evidence-414313', 'evidence-1115221']},
#  'claim-2687': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-896175', 'evidence-958716', 'evidence-949615']},
#  'claim-1294': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-406911', 'evidence-51588', 'evidence-108068']},
#  'claim-649': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-891205', 'evidence-309045', 'evidence-534559']},
#  'claim-2868': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1047721', 'evidence-78326', 'evidence-322939']},
#  'claim-1562': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1068751', 'evidence-562898', 'evidence-1177431']},
#  'claim-1620': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-460724', 'evidence-323266', 'evidence-716355']},
#  'claim-1327': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1098227', 'evidence-944830', 'evidence-1050398']},
#  'claim-3103': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1004521', 'evidence-1055682', 'evidence-1198789']},
#  'claim-195': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-29224', 'evidence-410087', 'evidence-617501']},
#  'claim-642': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-141844', 'evidence-873456', 'evidence-877608']},
#  'claim-2494': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-38396', 'evidence-117524', 'evidence-967158']},
#  'claim-1116': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-860207', 'evidence-618184', 'evidence-1047253']},
#  'claim-3048': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-823476', 'evidence-916975', 'evidence-528604']},
#  'claim-1115': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-540259', 'evidence-207999', 'evidence-850042']},
#  'claim-1614': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-135306', 'evidence-1116441', 'evidence-1144646']},
#  'claim-1580': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-439640', 'evidence-774652', 'evidence-175662']},
#  'claim-593': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-957572', 'evidence-358515', 'evidence-461068']},
#  'claim-2560': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-352802', 'evidence-829081', 'evidence-520022']},
#  'claim-11': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-140540', 'evidence-647814', 'evidence-384872']},
#  'claim-1339': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-421255', 'evidence-763909', 'evidence-590068']},
#  'claim-1878': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-452145', 'evidence-671023', 'evidence-592258']},
#  'claim-2120': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1142444', 'evidence-1174955', 'evidence-842']},
#  'claim-1098': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-220190', 'evidence-276290', 'evidence-901197']},
#  'claim-2078': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-589118', 'evidence-717597', 'evidence-550001']},
#  'claim-797': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-660755', 'evidence-1205331', 'evidence-223282']},
#  'claim-1667': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-896175', 'evidence-337528', 'evidence-397800']},
#  'claim-2553': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1016037', 'evidence-1015594', 'evidence-246671']},
#  'claim-2029': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-587423', 'evidence-326443', 'evidence-430244']},
#  'claim-1049': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-83796', 'evidence-1043585', 'evidence-205309']},
#  'claim-1744': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-183420', 'evidence-447033', 'evidence-1164059']},
#  'claim-2782': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-75712', 'evidence-1178290', 'evidence-879057']},
#  'claim-2432': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-905992', 'evidence-802686', 'evidence-384624']},
#  'claim-2805': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-18368', 'evidence-702474', 'evidence-741133']},
#  'claim-821': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-175224', 'evidence-434911', 'evidence-221235']},
#  'claim-1931': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1019192', 'evidence-776434', 'evidence-742185']},
#  'claim-1084': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-47245', 'evidence-647814', 'evidence-1180647']},
#  'claim-2788': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-27377', 'evidence-253026', 'evidence-297320']},
#  'claim-1465': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-637096', 'evidence-599485', 'evidence-857419']},
#  'claim-1938': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-485241', 'evidence-825299', 'evidence-1185776']},
#  'claim-2123': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-715970', 'evidence-974673', 'evidence-820660']},
#  'claim-1406': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-952233', 'evidence-130311', 'evidence-581402']},
#  'claim-2444': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1017229', 'evidence-891435', 'evidence-943110']},
#  'claim-320': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-25719', 'evidence-927151', 'evidence-312377']},
#  'claim-1880': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1033499', 'evidence-453427', 'evidence-188213']},
#  'claim-263': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-238889', 'evidence-1000787', 'evidence-377252']},
#  'claim-663': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-689075', 'evidence-773419', 'evidence-602665']},
#  'claim-1995': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-70694', 'evidence-1153083', 'evidence-925834']},
#  'claim-2780': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-75472', 'evidence-831777', 'evidence-955891']},
#  'claim-2369': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-116754', 'evidence-263772', 'evidence-928548']},
#  'claim-2627': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-683543', 'evidence-724346', 'evidence-874431']},
#  'claim-1077': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1110867', 'evidence-1062826', 'evidence-427121']},
#  'claim-828': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1203675', 'evidence-535619', 'evidence-145028']},
#  'claim-2461': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-312377', 'evidence-542292', 'evidence-700183']},
#  'claim-2945': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-823476', 'evidence-322110', 'evidence-781822']},
#  'claim-2633': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1192488', 'evidence-431803', 'evidence-97974']},
#  'claim-353': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-789848', 'evidence-677298', 'evidence-759337']},
#  'claim-1829': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-283191', 'evidence-566907', 'evidence-1003462']},
#  'claim-1568': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-56199', 'evidence-29963', 'evidence-192454']},
#  'claim-791': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-184832', 'evidence-318463', 'evidence-873503']},
#  'claim-1634': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-158280', 'evidence-18368', 'evidence-352317']},
#  'claim-2202': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-335835', 'evidence-31308', 'evidence-323097']},
#  'claim-337': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-491773', 'evidence-1071398', 'evidence-120967']},
#  'claim-1674': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368192', 'evidence-282556', 'evidence-675527']},
#  'claim-2255': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-762707', 'evidence-623810', 'evidence-663304']},
#  'claim-1988': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1018376', 'evidence-462344', 'evidence-825299']},
#  'claim-1376': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-479642', 'evidence-180923', 'evidence-527805']},
#  'claim-2649': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-842', 'evidence-32639', 'evidence-494273']},
#  'claim-1923': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-886916', 'evidence-925834', 'evidence-341764']},
#  'claim-133': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-573050', 'evidence-700836', 'evidence-1107184']},
#  'claim-2927': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-98914', 'evidence-100018', 'evidence-1020318']},
#  'claim-688': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-464979', 'evidence-53555', 'evidence-565011']},
#  'claim-1712': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-835510', 'evidence-1021635', 'evidence-734872']},
#  'claim-1817': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1056044', 'evidence-361095', 'evidence-898255']},
#  'claim-2067': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-280204', 'evidence-240134', 'evidence-589546']},
#  'claim-3052': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1183264', 'evidence-1197833', 'evidence-325821']},
#  'claim-1157': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-35432', 'evidence-584387', 'evidence-1164178']},
#  'claim-1246': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-22578', 'evidence-24537', 'evidence-482196']},
#  'claim-564': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-988909', 'evidence-153898', 'evidence-828546']},
#  'claim-1866': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-968233', 'evidence-571136', 'evidence-832140']},
#  'claim-1454': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-507225', 'evidence-1118522', 'evidence-863843']},
#  'claim-129': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-464979', 'evidence-117469', 'evidence-53555']},
#  'claim-1616': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-774035', 'evidence-856137', 'evidence-114562']},
#  'claim-1948': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-99027', 'evidence-69924', 'evidence-934267']},
#  'claim-614': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-268817', 'evidence-359987', 'evidence-289541']},
#  'claim-868': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-902675', 'evidence-798087', 'evidence-335187']},
#  'claim-1665': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1009038', 'evidence-1049076', 'evidence-175662']},
#  'claim-2453': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-69387', 'evidence-322110', 'evidence-545279']},
#  'claim-2267': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1092546', 'evidence-50498', 'evidence-790574']},
#  'claim-390': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-408551', 'evidence-683950', 'evidence-556369']},
#  'claim-216': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-557607', 'evidence-325549', 'evidence-964861']},
#  'claim-905': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-668672', 'evidence-288193', 'evidence-94272']},
#  'claim-2826': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-312377', 'evidence-996913', 'evidence-397800']},
#  'claim-2775': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1061949', 'evidence-567076', 'evidence-949961']},
#  'claim-2141': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-428977', 'evidence-1074029', 'evidence-130311']},
#  'claim-2482': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-452996', 'evidence-362027', 'evidence-280331']},
#  'claim-582': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-56671', 'evidence-1047562', 'evidence-820551']},
#  'claim-708': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-783750', 'evidence-269694', 'evidence-189944']},
#  'claim-412': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-219780', 'evidence-25719', 'evidence-625160']},
#  'claim-1855': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-345183', 'evidence-960892', 'evidence-944465']},
#  'claim-1999': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-22668', 'evidence-742544', 'evidence-1006052']},
#  'claim-3130': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-677955', 'evidence-1023859', 'evidence-479999']},
#  'claim-85': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-255466', 'evidence-12011', 'evidence-368819']},
#  'claim-2030': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-580104', 'evidence-376524', 'evidence-832658']},
#  'claim-470': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1088556', 'evidence-973645', 'evidence-698376']},
#  'claim-1932': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-15351', 'evidence-1058864', 'evidence-663519']},
#  'claim-2506': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-502244', 'evidence-1168151', 'evidence-968233']},
#  'claim-1825': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-660624', 'evidence-235172', 'evidence-1032278']},
#  'claim-1007': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1180647', 'evidence-914228', 'evidence-648764']},
#  'claim-1205': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-836767', 'evidence-1172970', 'evidence-933437']},
#  'claim-1783': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-194471', 'evidence-259736', 'evidence-1059586']},
#  'claim-2365': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-435467', 'evidence-825836', 'evidence-1016625']},
#  'claim-548': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-549640', 'evidence-934925', 'evidence-403688']},
#  'claim-2256': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-714864', 'evidence-616168', 'evidence-364767']},
#  'claim-3121': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-886611', 'evidence-603154', 'evidence-889770']},
#  'claim-2238': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-855683', 'evidence-1161423', 'evidence-976285']},
#  'claim-2844': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-183420', 'evidence-1164059', 'evidence-636423']},
#  'claim-789': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-987398', 'evidence-386503', 'evidence-859772']},
#  'claim-1143': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-259635', 'evidence-205577', 'evidence-142436']},
#  'claim-638': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-613875', 'evidence-838627', 'evidence-264954']},
#  'claim-1293': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1047395', 'evidence-558003', 'evidence-136165']},
#  'claim-1793': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-967158', 'evidence-1172097', 'evidence-678909']},
#  'claim-1631': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-113883', 'evidence-1075529', 'evidence-578355']},
#  'claim-382': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-237709', 'evidence-668736', 'evidence-851400']},
#  'claim-2052': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-66273', 'evidence-421255', 'evidence-815628']},
#  'claim-2304': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-798926', 'evidence-535215', 'evidence-565974']},
#  'claim-622': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-917371', 'evidence-542172', 'evidence-664933']},
#  'claim-2245': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-823476', 'evidence-843608', 'evidence-1202023']},
#  'claim-2835': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1083915', 'evidence-29963', 'evidence-616091']},
#  'claim-1314': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-573211', 'evidence-401776', 'evidence-420023']},
#  'claim-2821': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-439954', 'evidence-323097', 'evidence-1077486']},
#  'claim-666': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-941110', 'evidence-451862', 'evidence-881483']},
#  'claim-788': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-672232', 'evidence-1039421', 'evidence-1070890']},
#  'claim-802': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-980959', 'evidence-657030', 'evidence-755175']},
#  'claim-1827': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-477022', 'evidence-269345', 'evidence-531653']},
#  'claim-1688': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-505601', 'evidence-1115302', 'evidence-924217']},
#  'claim-366': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-303954', 'evidence-1125449', 'evidence-62464']},
#  'claim-967': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1142444', 'evidence-1174955', 'evidence-752013']},
#  'claim-2886': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-418126', 'evidence-489593', 'evidence-76693']},
#  'claim-1082': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-233716', 'evidence-12353', 'evidence-662251']},
#  'claim-2746': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-113883', 'evidence-581348', 'evidence-1122564']},
#  'claim-519': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-92688', 'evidence-1092088', 'evidence-502252']},
#  'claim-1119': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1182383', 'evidence-596428', 'evidence-183420']},
#  'claim-424': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-627319', 'evidence-497518', 'evidence-1108581']},
#  'claim-1606': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-41353', 'evidence-569840', 'evidence-236595']},
#  'claim-1279': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-432225', 'evidence-723045', 'evidence-269694']},
#  'claim-344': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-600112', 'evidence-457045', 'evidence-789848']},
#  'claim-2689': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1011992', 'evidence-1040824', 'evidence-769169']},
#  'claim-358': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-395391', 'evidence-1180097', 'evidence-425764']},
#  'claim-630': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-227406', 'evidence-825008', 'evidence-231873']},
#  'claim-633': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-53555', 'evidence-117469', 'evidence-149013']},
#  'claim-2384': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-646945', 'evidence-678431', 'evidence-64043']},
#  'claim-2536': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1034555', 'evidence-314022', 'evidence-598168']},
#  'claim-1512': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-525405', 'evidence-871977', 'evidence-1975']},
#  'claim-2953': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-611490', 'evidence-1204265', 'evidence-1089445']},
#  'claim-2127': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-880742', 'evidence-320402', 'evidence-578233']},
#  'claim-1576': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-83579', 'evidence-542292', 'evidence-973064']},
#  'claim-1170': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-464979', 'evidence-65928', 'evidence-325440']},
#  'claim-565': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-726463', 'evidence-1141320', 'evidence-597722']},
#  'claim-2288': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1059169', 'evidence-989213', 'evidence-975125']},
#  'claim-3039': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-557380', 'evidence-742544', 'evidence-322110']},
#  'claim-1844': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-995728', 'evidence-919879', 'evidence-540010']},
#  'claim-168': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-349531', 'evidence-262827', 'evidence-817759']},
#  'claim-1067': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-420138', 'evidence-288835', 'evidence-1119853']},
#  'claim-1183': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-673660', 'evidence-76083', 'evidence-894556']},
#  'claim-1625': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-504247', 'evidence-110432', 'evidence-11661']},
#  'claim-2032': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-563312', 'evidence-948219', 'evidence-135946']},
#  'claim-57': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-922981', 'evidence-655508', 'evidence-367175']},
#  'claim-1544': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-824669', 'evidence-1172097', 'evidence-867263']},
#  'claim-2549': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-976802', 'evidence-1034966', 'evidence-106535']},
#  'claim-446': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-577890', 'evidence-1177431', 'evidence-417595']},
#  'claim-2591': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-553459', 'evidence-487707', 'evidence-531242']},
#  'claim-1890': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-68170', 'evidence-217211', 'evidence-1036944']},
#  'claim-51': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1050099', 'evidence-453635', 'evidence-100018']},
#  'claim-2779': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1171250', 'evidence-549103', 'evidence-676679']},
#  'claim-2856': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-725436', 'evidence-825836', 'evidence-720171']},
#  'claim-2358': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-892616', 'evidence-51588', 'evidence-149105']},
#  'claim-982': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-457045', 'evidence-1156947', 'evidence-717597']},
#  'claim-1592': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1094467', 'evidence-1154657', 'evidence-503460']},
#  'claim-2664': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-718657', 'evidence-940597', 'evidence-123812']},
#  'claim-2100': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-138717', 'evidence-638159', 'evidence-823899']},
#  'claim-2641': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-222194', 'evidence-1161423', 'evidence-735048']},
#  'claim-2242': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1160125', 'evidence-608403', 'evidence-66273']},
#  'claim-2132': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-932918', 'evidence-361081', 'evidence-1164550']},
#  'claim-1806': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-557203', 'evidence-1154657', 'evidence-823476']},
#  'claim-197': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-450316', 'evidence-1186170', 'evidence-561302']},
#  'claim-2262': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1061949', 'evidence-32639', 'evidence-236007']},
#  'claim-74': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-980959', 'evidence-660755', 'evidence-479557']},
#  'claim-357': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-880838', 'evidence-1187336', 'evidence-53154']},
#  'claim-888': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1183264', 'evidence-697238', 'evidence-1092088']},
#  'claim-1714': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-191678', 'evidence-671685', 'evidence-1167830']},
#  'claim-2620': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-338987', 'evidence-991415', 'evidence-1027987']},
#  'claim-1772': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-712289', 'evidence-1054346', 'evidence-427518']},
#  'claim-2387': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-414560', 'evidence-1198644', 'evidence-1039123']},
#  'claim-1331': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-499734', 'evidence-66273', 'evidence-403020']},
#  'claim-1669': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-98914', 'evidence-202936', 'evidence-1037784']},
#  'claim-555': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-911411', 'evidence-936291', 'evidence-625517']},
#  'claim-1653': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-734370', 'evidence-905697', 'evidence-573620']},
#  'claim-248': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-80853', 'evidence-108078', 'evidence-274044']},
#  'claim-1303': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-288193', 'evidence-1014706', 'evidence-1059606']},
#  'claim-906': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1146282', 'evidence-34759', 'evidence-648764']},
#  'claim-2692': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-9075', 'evidence-479999', 'evidence-677955']},
#  'claim-1901': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368882', 'evidence-1158029', 'evidence-856068']},
#  'claim-6': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-534891', 'evidence-1166990', 'evidence-399226']},
#  'claim-1539': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-285141', 'evidence-1115252', 'evidence-900907']},
#  'claim-87': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-357219', 'evidence-490170', 'evidence-235043']},
#  'claim-194': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-417595', 'evidence-760688', 'evidence-152676']},
#  'claim-95': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-759337', 'evidence-879500', 'evidence-1055682']},
#  'claim-1109': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-519943', 'evidence-817308', 'evidence-225191']},
#  'claim-583': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-774927', 'evidence-970539', 'evidence-243276']},
#  'claim-1374': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-968233', 'evidence-95610', 'evidence-1042452']},
#  'claim-819': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-890240', 'evidence-839895', 'evidence-452901']},
#  'claim-1962': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-483913', 'evidence-38396', 'evidence-1108283']},
#  'claim-2822': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-340958', 'evidence-291540', 'evidence-986018']},
#  'claim-1130': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-508793', 'evidence-711111', 'evidence-1066389']},
#  'claim-1675': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-964047', 'evidence-26359', 'evidence-668716']},
#  'claim-1577': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-880742', 'evidence-320402', 'evidence-578233']},
#  'claim-2587': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-383274', 'evidence-983833', 'evidence-1100614']},
#  'claim-473': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-619901', 'evidence-263527', 'evidence-689765']},
#  'claim-1090': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-616446', 'evidence-882910', 'evidence-185758']},
#  'claim-2877': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-141322', 'evidence-995071', 'evidence-565446']},
#  'claim-1794': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-560243', 'evidence-136793', 'evidence-668122']},
#  'claim-1175': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-964047', 'evidence-26359', 'evidence-1080833']},
#  'claim-1055': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-926283', 'evidence-1080833', 'evidence-881808']},
#  'claim-1296': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1001780', 'evidence-287752', 'evidence-883543']},
#  'claim-1326': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-615238', 'evidence-348427', 'evidence-894129']},
#  'claim-3034': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-834015', 'evidence-401938', 'evidence-970912']},
#  'claim-1452': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-682177', 'evidence-319975', 'evidence-496214']},
#  'claim-1460': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-82325', 'evidence-636423', 'evidence-514779']},
#  'claim-1575': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1116441', 'evidence-1013303', 'evidence-591257']},
#  'claim-3047': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-39175', 'evidence-752115', 'evidence-956954']},
#  'claim-3009': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-651544', 'evidence-531856', 'evidence-122441']},
#  'claim-1871': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-660624', 'evidence-235172', 'evidence-1160675']},
#  'claim-2948': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-996913', 'evidence-835510', 'evidence-847568']},
#  'claim-1533': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-469998', 'evidence-1129603', 'evidence-53757']},
#  'claim-1308': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-307645', 'evidence-1198124', 'evidence-265967']},
#  'claim-1579': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-128422', 'evidence-397800', 'evidence-540307']},
#  'claim-1968': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-259826', 'evidence-36994', 'evidence-675527']},
#  'claim-447': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-488727', 'evidence-100171', 'evidence-551522']},
#  'claim-1394': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-448831', 'evidence-321705', 'evidence-211200']},
#  'claim-1530': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-683927', 'evidence-464396', 'evidence-635378']},
#  'claim-1662': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-790637', 'evidence-1003706', 'evidence-447955']},
#  'claim-19': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-12425', 'evidence-530201', 'evidence-1100614']},
#  'claim-2706': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-671685', 'evidence-295217', 'evidence-638880']},
#  'claim-1299': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-8304', 'evidence-680558', 'evidence-1045522']},
#  'claim-2048': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-417595', 'evidence-179283', 'evidence-760688']},
#  'claim-108': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-57975', 'evidence-325988', 'evidence-584943']},
#  'claim-2040': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-522347', 'evidence-71691', 'evidence-395910']},
#  'claim-310': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-647536', 'evidence-554535', 'evidence-138622']},
#  'claim-1410': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-552367', 'evidence-214354', 'evidence-554990']},
#  'claim-1010': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1133069', 'evidence-240134', 'evidence-1137064']},
#  'claim-343': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-755175', 'evidence-1045522', 'evidence-416007']},
#  'claim-2161': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-730469', 'evidence-121187', 'evidence-677627']},
#  'claim-1659': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-235409', 'evidence-881483', 'evidence-914173']},
#  'claim-41': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1062446', 'evidence-590553', 'evidence-1150927']},
#  'claim-1555': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1081418', 'evidence-975177', 'evidence-280331']},
#  'claim-960': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1174955', 'evidence-637842', 'evidence-1130952']},
#  'claim-1023': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-731961', 'evidence-195294', 'evidence-575649']},
#  'claim-527': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-829081', 'evidence-270394', 'evidence-333085']},
#  'claim-98': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-294163', 'evidence-530108', 'evidence-891265']},
#  'claim-3056': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-405992', 'evidence-52772', 'evidence-900907']},
#  'claim-1869': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-449150', 'evidence-54039', 'evidence-500595']},
#  'claim-2891': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-782976', 'evidence-640229', 'evidence-19306']},
#  'claim-2268': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1092546', 'evidence-195568', 'evidence-50498']},
#  'claim-737': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-753246', 'evidence-843494', 'evidence-954920']},
#  'claim-1943': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1154657', 'evidence-890015', 'evidence-346869']},
#  'claim-2114': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-984945', 'evidence-504723', 'evidence-175896']},
#  'claim-2871': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-35720', 'evidence-946400', 'evidence-197453']},
#  'claim-1468': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-271936', 'evidence-772442', 'evidence-107843']},
#  'claim-1640': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-384754', 'evidence-274002', 'evidence-358571']},
#  'claim-2336': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-194897', 'evidence-1007525', 'evidence-617070']},
#  'claim-1315': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-907893', 'evidence-348427', 'evidence-573211']},
#  'claim-2493': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1113800', 'evidence-1149025', 'evidence-763082']},
#  'claim-2208': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-957593', 'evidence-939303', 'evidence-98115']},
#  'claim-2522': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-333326', 'evidence-685129', 'evidence-285231']},
#  'claim-581': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-558782', 'evidence-413590', 'evidence-975948']},
#  'claim-1598': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1054346', 'evidence-1093172', 'evidence-1163186']},
#  'claim-745': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-683138', 'evidence-426947', 'evidence-1039181']},
#  'claim-1449': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-331238', 'evidence-611208', 'evidence-118140']},
#  'claim-2887': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-430244', 'evidence-489414', 'evidence-430265']},
#  'claim-1877': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-477022', 'evidence-910990', 'evidence-1051620']},
#  'claim-1247': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-731434', 'evidence-957020', 'evidence-114604']},
#  'claim-1017': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-860703', 'evidence-381660', 'evidence-272599']},
#  'claim-100': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1154657', 'evidence-877733', 'evidence-458959']},
#  'claim-2075': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-497518', 'evidence-325988', 'evidence-514779']},
#  'claim-279': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-842', 'evidence-494273', 'evidence-1068857']},
#  'claim-2903': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-897952', 'evidence-678783', 'evidence-136399']},
#  'claim-2460': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-625160', 'evidence-740744', 'evidence-129871']},
#  'claim-1919': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-22578', 'evidence-783900', 'evidence-24537']},
#  'claim-1024': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-760688', 'evidence-103918', 'evidence-1202023']},
#  'claim-235': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-483913', 'evidence-38396', 'evidence-1026164']},
# ...
#   'evidences': ['evidence-476616', 'evidence-103287', 'evidence-855683']},
#  'claim-2027': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-1068851', 'evidence-1013303', 'evidence-756019']},
#  'claim-954': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-94074', 'evidence-287464', 'evidence-1067341']},
#  'claim-128': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-363461', 'evidence-1127398', 'evidence-325988']},
#  'claim-1513': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-454968', 'evidence-57767', 'evidence-675527']},
#  'claim-1784': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-823476', 'evidence-17867', 'evidence-829919']},
#  'claim-2284': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-989213', 'evidence-611285', 'evidence-83579']},
#  'claim-2939': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-417353', 'evidence-99526', 'evidence-621065']},
#  'claim-2221': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-139763', 'evidence-329101', 'evidence-974673']},
#  'claim-1559': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1029618', 'evidence-269791', 'evidence-207443']},
#  'claim-2381': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-737964', 'evidence-95057', 'evidence-64043']},
#  'claim-1435': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-127513', 'evidence-60918', 'evidence-55562']},
#  'claim-2317': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-464979', 'evidence-57975', 'evidence-871998']},
#  'claim-889': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-333167', 'evidence-158510', 'evidence-198157']},
#  'claim-1480': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-719544', 'evidence-861701', 'evidence-498557']},
#  'claim-311': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-539221', 'evidence-275823', 'evidence-626410']},
#  'claim-2457': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-25719', 'evidence-454757', 'evidence-1092088']},
#  'claim-2009': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1200540', 'evidence-928281', 'evidence-443958']},
#  'claim-2949': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-165974', 'evidence-150058', 'evidence-469480']},
#  'claim-661': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-24537', 'evidence-451862', 'evidence-596428']},
#  'claim-469': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-147265', 'evidence-958600', 'evidence-71166']},
#  'claim-31': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-502356', 'evidence-186411', 'evidence-22668']},
#  'claim-1953': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-774181', 'evidence-926734', 'evidence-541553']},
#  'claim-862': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-559817', 'evidence-291132', 'evidence-336493']},
#  'claim-2910': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-608014', 'evidence-58213', 'evidence-368473']},
#  'claim-692': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1049371', 'evidence-1196885', 'evidence-823476']},
#  'claim-2295': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-667754', 'evidence-1038785', 'evidence-1012785']},
#  'claim-2520': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1132945', 'evidence-1186362', 'evidence-854585']},
#  'claim-2499': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-792207', 'evidence-179644', 'evidence-1055320']},
#  'claim-1253': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-53555', 'evidence-502244', 'evidence-465117']},
#  'claim-1690': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1080833', 'evidence-714675', 'evidence-823476']},
#  'claim-3062': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-465117', 'evidence-53555', 'evidence-153174']},
#  'claim-1566': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-108582', 'evidence-526721', 'evidence-1009949']},
#  'claim-2489': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1169414', 'evidence-477915', 'evidence-1028174']},
#  'claim-1145': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-22578', 'evidence-482300', 'evidence-357997']},
#  'claim-1079': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1087382', 'evidence-490170', 'evidence-1088556']},
#  'claim-2997': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1016554', 'evidence-1117728', 'evidence-955425']},
#  'claim-2839': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1200633', 'evidence-158280', 'evidence-710110']},
#  'claim-2157': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-823476', 'evidence-196937', 'evidence-916975']},
#  'claim-236': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1183264', 'evidence-832140', 'evidence-697238']},
#  'claim-2312': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-221826', 'evidence-1186870', 'evidence-781836']},
#  'claim-531': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-67732', 'evidence-572512', 'evidence-984053']},
#  'claim-2721': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-627319', 'evidence-497518', 'evidence-1192617']},
#  'claim-246': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-504449', 'evidence-683138', 'evidence-1184104']},
#  'claim-2171': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-774035', 'evidence-114562', 'evidence-856137']},
#  'claim-741': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1160406', 'evidence-196647', 'evidence-474380']},
#  'claim-1350': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-171634', 'evidence-913486', 'evidence-884484']},
#  'claim-1945': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-755661', 'evidence-854169', 'evidence-100674']},
#  'claim-2556': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1114181', 'evidence-930341', 'evidence-803857']},
#  'claim-776': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-862739', 'evidence-1023964', 'evidence-147465']},
#  'claim-335': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-472882', 'evidence-556258', 'evidence-222593']},
#  'claim-1578': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-323097', 'evidence-1154657', 'evidence-1094467']},
#  'claim-901': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-755629', 'evidence-138929', 'evidence-478106']},
#  'claim-2319': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1075529', 'evidence-934607', 'evidence-113883']},
#  'claim-1121': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-733280', 'evidence-332154', 'evidence-118577']},
#  'claim-728': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-435467', 'evidence-1007847', 'evidence-253690']},
#  'claim-1507': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1154657', 'evidence-877733', 'evidence-157348']},
#  'claim-2153': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-817044', 'evidence-511606', 'evidence-334431']},
#  'claim-2807': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-972542', 'evidence-544804', 'evidence-917435']},
#  'claim-1386': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-758943', 'evidence-110772', 'evidence-770835']},
#  'claim-2897': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-602868', 'evidence-880254', 'evidence-45548']},
#  'claim-1164': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-325870', 'evidence-775277', 'evidence-833979']},
#  'claim-1305': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-323266', 'evidence-513559', 'evidence-1198124']},
#  'claim-3122': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-527309', 'evidence-886696', 'evidence-469480']},
#  'claim-127': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-69387', 'evidence-121664', 'evidence-969696']},
#  'claim-2318': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-621138', 'evidence-197453', 'evidence-1103719']},
#  'claim-699': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-476848', 'evidence-1081912', 'evidence-1198348']},
#  'claim-2374': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-417595', 'evidence-179283', 'evidence-706949']},
#  'claim-2038': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-457045', 'evidence-932986', 'evidence-906284']},
#  'claim-142': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-723045', 'evidence-1169077', 'evidence-1029618']},
#  'claim-495': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1194038', 'evidence-302241', 'evidence-1185033']},
#  'claim-2539': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-477915', 'evidence-742544', 'evidence-515216']},
#  'claim-695': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-38904', 'evidence-676545', 'evidence-264228']},
#  'claim-1715': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-647814', 'evidence-384872', 'evidence-1057929']},
#  'claim-306': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-13434', 'evidence-457045', 'evidence-1198065']},
#  'claim-1445': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1087867', 'evidence-331238', 'evidence-91099']},
#  'claim-3105': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-441733', 'evidence-1150379', 'evidence-110835']},
#  'claim-2799': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1877', 'evidence-700717', 'evidence-1161351']},
#  'claim-1952': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-482196', 'evidence-731434', 'evidence-604437']},
#  'claim-2011': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-581537', 'evidence-268461', 'evidence-33883']},
#  'claim-945': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-966234', 'evidence-1049354', 'evidence-318640']},
#  'claim-1479': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1177431', 'evidence-162797', 'evidence-881808']},
#  'claim-1702': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-620691', 'evidence-785695', 'evidence-648764']},
#  'claim-196': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-599105', 'evidence-707516', 'evidence-190063']},
#  'claim-2495': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1113800', 'evidence-1149025', 'evidence-614890']},
#  'claim-190': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-141026', 'evidence-1034813', 'evidence-479999']},
#  'claim-2431': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-689765', 'evidence-56331', 'evidence-402844']},
#  'claim-230': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-161134', 'evidence-414446', 'evidence-1073893']},
#  'claim-2122': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1205435', 'evidence-866970', 'evidence-581348']},
#  'claim-1603': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-308548', 'evidence-87673', 'evidence-647382']},
#  'claim-2538': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-281372', 'evidence-1075757', 'evidence-354463']},
#  'claim-3024': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-577488', 'evidence-512887', 'evidence-458761']},
#  'claim-1751': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-281927', 'evidence-998193', 'evidence-75600']},
#  'claim-880': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-117524', 'evidence-1062959', 'evidence-114562']},
#  'claim-1618': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-927151', 'evidence-814790', 'evidence-843608']},
#  'claim-435': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-774927', 'evidence-532405', 'evidence-507554']},
#  'claim-2323': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1096169', 'evidence-430265', 'evidence-809116']},
#  'claim-1342': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-612847', 'evidence-667089', 'evidence-1198065']},
#  'claim-1265': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-717597', 'evidence-533052', 'evidence-4674']},
#  'claim-1946': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1149104', 'evidence-838518', 'evidence-492421']},
#  'claim-1503': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-660755', 'evidence-222883', 'evidence-223282']},
#  'claim-2766': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-871610', 'evidence-281727', 'evidence-352954']},
#  'claim-1523': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1028174', 'evidence-183341', 'evidence-1169414']},
#  'claim-2024': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-732260', 'evidence-554093', 'evidence-143961']},
#  'claim-2047': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-322110', 'evidence-34759', 'evidence-1146282']},
#  'claim-2500': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-388348', 'evidence-183056', 'evidence-812311']},
#  'claim-2935': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-157348', 'evidence-1068819', 'evidence-881508']},
#  'claim-3058': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1183264', 'evidence-742898', 'evidence-817759']},
#  'claim-1859': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1136426', 'evidence-632366', 'evidence-1199602']},
#  'claim-1654': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-615051', 'evidence-542610', 'evidence-829034']},
#  'claim-1186': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-926893', 'evidence-676123', 'evidence-1118256']},
#  'claim-823': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-508793', 'evidence-268048', 'evidence-420577']},
#  'claim-2918': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1078887', 'evidence-99027', 'evidence-308147']},
#  'claim-1532': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-588652', 'evidence-734286', 'evidence-1159499']},
#  'claim-1169': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-71166', 'evidence-1192617', 'evidence-363461']},
#  'claim-2128': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-323097', 'evidence-1154657', 'evidence-31308']},
#  'claim-3005': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-1202023', 'evidence-979414', 'evidence-525405']},
#  'claim-1921': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-1004471', 'evidence-1048912', 'evidence-686100']},
#  'claim-2395': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-858437', 'evidence-1200633', 'evidence-640229']},
#  'claim-2800': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-632574', 'evidence-329363', 'evidence-371208']},
#  'claim-3049': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-100018', 'evidence-823476', 'evidence-322110']},
#  'claim-3008': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-775673', 'evidence-1020725', 'evidence-333167']},
#  'claim-997': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-800880', 'evidence-532524', 'evidence-740867']},
#  'claim-2614': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-563360', 'evidence-512615', 'evidence-616623']},
#  'claim-816': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-224415', 'evidence-76224', 'evidence-283082']},
#  'claim-1347': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-88585', 'evidence-977735', 'evidence-843054']},
#  'claim-2843': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-514779', 'evidence-359806', 'evidence-701955']},
#  'claim-1789': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-866495', 'evidence-1075865', 'evidence-121187']},
#  'claim-482': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-200776', 'evidence-391155', 'evidence-322393']},
#  'claim-805': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-331462', 'evidence-639435', 'evidence-806971']},
#  'claim-2630': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1192488', 'evidence-406963', 'evidence-1206310']},
#  'claim-1464': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-658407', 'evidence-926240', 'evidence-626410']},
#  'claim-2562': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-828120', 'evidence-771238', 'evidence-391045']},
#  'claim-724': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368819', 'evidence-329177', 'evidence-572667']},
#  'claim-615': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-269919', 'evidence-883543', 'evidence-381374']},
#  ...}
